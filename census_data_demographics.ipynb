# %% [markdown]
# # Census Data for San Antonio Districts

# %%
import pandas as pd
import numpy as np
import re

from ccd_functions import read_distict, cal_counts, cal_district_numbers

# %% [markdown]
# ## District Data

# %% [markdown]
# This sheet tells which district each census tract aligns with and what percentage of the district is included. District 0 are census tracts outside of San Antonio.

# %%
dist = read_distict()
dist.head()
# Out:
#    council   tract   percent
# 0      1.0  192000  0.221309
# 1      1.0  191900  0.000049
# 2      1.0  192300  0.185373
# 3      1.0  192100  0.572719
# 4      1.0  191304  0.786238

# %% [markdown]
# ## Census Data

# %% [markdown]
# This is all the data pulled from the census.

# %%
filename = 'ACSDP5Y2021.DP05-Data.csv'
filename2 = 'ACSDP5Y2021.DP05-Column-Metadata.csv'

# %%
dataall = pd.read_csv(filename)
dataall.columns = dataall.columns.str.lower()

dataall = dataall.iloc[1:].reset_index(drop=True)
# dataall = dataall.replace('(X)', np.nan).replace('-',np.nan).replace('**',np.nan)
# dataall = dataall.dropna(axis=1, how='all')

dataall.geo_id = dataall.geo_id.str[-6:]
dataall.geo_id = dataall.geo_id.astype(str)
dataall = dataall.drop(columns='name')

dataall.head()
# Out:
#    geo_id dp05_0001e dp05_0001ea dp05_0001m dp05_0001ma dp05_0002e dp05_0002m  \
# 0  110100       2934         NaN        565         NaN       1698        365
# 1  110300       2930         NaN        652         NaN       1444        456
# 2  110500       2201         NaN        309         NaN       1030        198
# 3  110600       5384         NaN       1620         NaN       4117       1585
# 4  110700        982         NaN        246         NaN        525        148
#
#   dp05_0002ma dp05_0002ea dp05_0003e  ... dp05_0087pea dp05_0088pe  \
# 0         NaN         NaN       1236  ...          NaN        53.2
# 1         NaN         NaN       1486  ...          NaN        49.8
# 2         NaN         NaN       1171  ...          NaN        39.2
# 3         NaN         NaN       1267  ...          NaN        77.6
# 4         NaN         NaN        457  ...          NaN        52.8
#
#   dp05_0088pm dp05_0088pma dp05_0088pea dp05_0089pe dp05_0089pm dp05_0089pma  \
# 0         8.7          NaN          NaN        46.8         8.7          NaN
# 1         6.8          NaN          NaN        50.2         6.8          NaN
# 2         6.8          NaN          NaN        60.8         6.8          NaN
# 3         8.5          NaN          NaN        22.4         8.5          NaN
# 4         6.9          NaN          NaN        47.2         6.9          NaN
#
#   dp05_0089pea unnamed: 714
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#
# [5 rows x 714 columns]

# %% [markdown]
# ## Labels

# %% [markdown]
# These are the labels for the census data.

# %%
labels = pd.read_csv(filename2)
labels.columns = labels.columns.str.lower().str.replace('\W+','_', regex=True)
labels.column_name = labels.column_name.str.lower()

labels = labels [labels.label.str.startswith('Estimate')]
labels = labels [~labels.label.str.contains('ratio')]

groups = labels.label.str.split('!', expand=True)[2].unique()
groups
# Out:
# array(['SEX AND AGE', 'RACE',
#        'Race alone or in combination with one or more other races',
#        'HISPANIC OR LATINO AND RACE', 'Total housing units',
#        'CITIZEN, VOTING AGE POPULATION'], dtype=object)

# %% [markdown]
# ## Now combine and calculate!

# %% [markdown]
# ### Sex and Age

# %%
grouping = groups[0]
print(grouping)
print()

current_labels = labels [labels.label.str.contains(grouping)]
# current_labels = current_labels.iloc[1:]
current_labels = current_labels.iloc[:-13]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
    
final1 = cal_district_numbers(dist, dataall, labels, labels_check, 'DP05_0001E')
final1
# Out:
# SEX AND AGE
#
# Estimate!!SEX AND AGE!!Total population
# Estimate!!SEX AND AGE!!Total population!!Male
# Estimate!!SEX AND AGE!!Total population!!Female
# Estimate!!SEX AND AGE!!Total population!!Under 5 years
# Estimate!!SEX AND AGE!!Total population!!5 to 9 years
# Estimate!!SEX AND AGE!!Total population!!10 to 14 years
# Estimate!!SEX AND AGE!!Total population!!15 to 19 years
# Estimate!!SEX AND AGE!!Total population!!20 to 24 years
# Estimate!!SEX AND AGE!!Total population!!25 to 34 years
# Estimate!!SEX AND AGE!!Total population!!35 to 44 years
# Estimate!!SEX AND AGE!!Total population!!45 to 54 years
# Estimate!!SEX AND AGE!!Total population!!55 to 59 years
# Estimate!!SEX AND AGE!!Total population!!60 to 64 years
# Estimate!!SEX AND AGE!!Total population!!65 to 74 years
# Estimate!!SEX AND AGE!!Total population!!75 to 84 years
# Estimate!!SEX AND AGE!!Total population!!85 years and over
#                                           0          1          2          3  \
# Total population counts           484420.83  137461.90  130625.49  140848.63
# Total population counts percent        0.26       0.07       0.07       0.08
# Total population moe                8608.46    3922.65    4282.35    4040.20
# Total population moa percent           0.01       0.02       0.02       0.02
# Male counts                       242448.52   66884.38   64660.66   70788.79
# ...                                     ...        ...        ...        ...
# 75 to 84 years moa percent             0.04       0.07       0.06       0.06
# 85 years and over counts            5047.90    2856.40    1327.99    1891.75
# 85 years and over counts percent       0.00       0.00       0.00       0.00
# 85 years and over moe                676.09     427.42     208.76     355.48
# 85 years and over moa percent          0.08       0.09       0.10       0.11
#
#                                           4          5          6          7  \
# Total population counts           132734.78  141064.66  129776.89  152535.62
# Total population counts percent        0.07       0.08       0.07       0.08
# Total population moe                4164.93    4677.30    4401.06    4572.60
# Total population moa percent           0.02       0.02       0.02       0.02
# Male counts                        65588.17   71440.58   63237.06   74315.74
# ...                                     ...        ...        ...        ...
# 75 to 84 years moa percent             0.08       0.05       0.09       0.05
# 85 years and over counts            1401.79    2604.57    1117.18    3337.94
# 85 years and over counts percent       0.00       0.00       0.00       0.00
# 85 years and over moe                288.01     422.32     286.34     642.64
# 85 years and over moa percent          0.12       0.10       0.16       0.12
#
#                                           8          9         10
# Total population counts           145193.17  120314.07  141125.95
# Total population counts percent        0.08       0.06       0.08
# Total population moe                3805.53    3340.46    3831.35
# Total population moa percent           0.02       0.02       0.02
# Male counts                        73678.74   58915.46   67451.91
# ...                                     ...        ...        ...
# 75 to 84 years moa percent             0.07       0.08       0.07
# 85 years and over counts            1986.00    1436.80    2626.68
# 85 years and over counts percent       0.00       0.00       0.00
# 85 years and over moe                454.51     276.44     457.30
# 85 years and over moa percent          0.14       0.12       0.11
#
# [64 rows x 11 columns]

# %% [markdown]
# ### Race

# %%
grouping = groups[1]
print(grouping)

current_labels = labels [labels.label.str.contains(grouping)]
# current_labels = current_labels.iloc[1:]
current_labels = current_labels.iloc[:-16]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
    
final2 = cal_district_numbers(dist, dataall, labels, labels_check, 'DP05_0033E')    
final2
# Out:
# RACE
# Estimate!!RACE!!Total population
# Estimate!!RACE!!Total population!!One race
# Estimate!!RACE!!Total population!!Two or more races
# Estimate!!RACE!!Total population!!One race
# Estimate!!RACE!!Total population!!One race!!White
# Estimate!!RACE!!Total population!!One race!!Black or African American
# Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native
# Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native!!Cherokee tribal grouping
# Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native!!Chippewa tribal grouping
# Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native!!Navajo tribal grouping
# Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native!!Sioux tribal grouping
# Estimate!!RACE!!Total population!!One race!!Asian
# Estimate!!RACE!!Total population!!One race!!Asian!!Asian Indian
# Estimate!!RACE!!Total population!!One race!!Asian!!Chinese
# Estimate!!RACE!!Total population!!One race!!Asian!!Filipino
# Estimate!!RACE!!Total population!!One race!!Asian!!Japanese
# Estimate!!RACE!!Total population!!One race!!Asian!!Korean
# Estimate!!RACE!!Total population!!One race!!Asian!!Vietnamese
# Estimate!!RACE!!Total population!!One race!!Asian!!Other Asian
# Estimate!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander
# Estimate!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander!!Native Hawaiian
# Estimate!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander!!Chamorro
# Estimate!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander!!Samoan
# Estimate!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander!!Other Pacific Islander
# Estimate!!RACE!!Total population!!One race!!Some other race
# Estimate!!RACE!!Total population!!Two or more races
# Estimate!!RACE!!Total population!!Two or more races!!White and Black or African American
# Estimate!!RACE!!Total population!!Two or more races!!White and American Indian and Alaska Native
# Estimate!!RACE!!Total population!!Two or more races!!White and Asian
# Estimate!!RACE!!Total population!!Two or more races!!Black or African American and American Indian and Alaska Native
# /Users/mists/Projects/sa2020/sa2020-ccd/ccd_functions.py:69: RuntimeWarning: divide by zero encountered in double_scalars
#   error_perc = round(math.sqrt(sum((subset.tru_error / 1.645)**2)) / count, 2)
#                                                             0          1  \
# Total population counts                             484420.83  137461.90
# Total population counts percent                          0.26       0.07
# Total population moe                                  8608.46    3922.65
# Total population moa percent                             0.01       0.02
# One race counts                                     411420.97  106806.23
# ...                                                       ...        ...
# Two or more races!!White and Asian moa percent           0.10       0.26
# Two or more races!!Black or African American an...     481.89      26.98
# Two or more races!!Black or African American an...       0.00       0.00
# Two or more races!!Black or African American an...     237.17      84.34
# Two or more races!!Black or African American an...       0.30       1.90
#
#                                                             2          3  \
# Total population counts                             130625.49  140848.63
# Total population counts percent                          0.07       0.08
# Total population moe                                  4282.35    4040.20
# Total population moa percent                             0.02       0.02
# One race counts                                     111762.96  120457.55
# ...                                                       ...        ...
# Two or more races!!White and Asian moa percent           0.30       0.41
# Two or more races!!Black or African American an...      97.77     107.49
# Two or more races!!Black or African American an...       0.00       0.00
# Two or more races!!Black or African American an...      92.06     142.15
# Two or more races!!Black or African American an...       0.57       0.80
#
#                                                             4          5  \
# Total population counts                             132734.78  141064.66
# Total population counts percent                          0.07       0.08
# Total population moe                                  4164.93    4677.30
# Total population moa percent                             0.02       0.02
# One race counts                                     113582.90  110427.12
# ...                                                       ...        ...
# Two or more races!!White and Asian moa percent           0.32       3.19
# Two or more races!!Black or African American an...      53.30      15.02
# Two or more races!!Black or African American an...       0.00       0.00
# Two or more races!!Black or African American an...      88.30      91.53
# Two or more races!!Black or African American an...       1.01       3.70
#
#                                                             6          7  \
# Total population counts                             129776.89  152535.62
# Total population counts percent                          0.07       0.08
# Total population moe                                  4401.06    4572.60
# Total population moa percent                             0.02       0.02
# One race counts                                     101370.31  123298.08
# ...                                                       ...        ...
# Two or more races!!White and Asian moa percent           0.20       0.20
# Two or more races!!Black or African American an...     158.23      40.86
# Two or more races!!Black or African American an...       0.00       0.00
# Two or more races!!Black or African American an...     152.46      88.51
# Two or more races!!Black or African American an...       0.59       1.32
#
#                                                             8          9  \
# Total population counts                             145193.17  120314.07
# Total population counts percent                          0.08       0.06
# Total population moe                                  3805.53    3340.46
# Total population moa percent                             0.02       0.02
# One race counts                                     123151.80  102051.69
# ...                                                       ...        ...
# Two or more races!!White and Asian moa percent           0.19       0.20
# Two or more races!!Black or African American an...      61.11     184.74
# Two or more races!!Black or African American an...       0.00       0.00
# Two or more races!!Black or African American an...     102.89     164.56
# Two or more races!!Black or African American an...       1.02       0.54
#
#                                                            10
# Total population counts                             141125.95
# Total population counts percent                          0.08
# Total population moe                                  3831.35
# Total population moa percent                             0.02
# One race counts                                     121739.40
# ...                                                       ...
# Two or more races!!White and Asian moa percent           0.20
# Two or more races!!Black or African American an...      25.64
# Two or more races!!Black or African American an...       0.00
# Two or more races!!Black or African American an...      83.57
# Two or more races!!Black or African American an...       1.98
#
# [120 rows x 11 columns]

# %% [markdown]
# ### More Race

# %%
grouping = groups[2]
print(grouping)
print()

current_labels = labels [labels.label.str.contains(grouping)]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
    
final3 = cal_district_numbers(dist, dataall, labels, labels_check, 'DP05_0063E')
final3
# Out:
# Race alone or in combination with one or more other races
#
# Estimate!!Race alone or in combination with one or more other races!!Total population
# Estimate!!Race alone or in combination with one or more other races!!Total population!!White
# Estimate!!Race alone or in combination with one or more other races!!Total population!!Black or African American
# Estimate!!Race alone or in combination with one or more other races!!Total population!!American Indian and Alaska Native
# Estimate!!Race alone or in combination with one or more other races!!Total population!!Asian
# Estimate!!Race alone or in combination with one or more other races!!Total population!!Native Hawaiian and Other Pacific Islander
# Estimate!!Race alone or in combination with one or more other races!!Total population!!Some other race
#                                                             0          1  \
# Total population counts                             484420.83  137461.90
# Total population counts percent                          0.26       0.07
# Total population moe                                  8608.46    3922.65
# Total population moa percent                             0.01       0.02
# White counts                                        380492.05  119145.64
# White counts percent                                     0.21       0.06
# White moe                                             8303.87    3852.14
# White moa percent                                        0.01       0.02
# Black or African American counts                     59084.61    5721.92
# Black or African American counts percent                 0.03       0.00
# Black or African American moe                         3054.90     903.75
# Black or African American moa percent                    0.03       0.10
# American Indian and Alaska Native counts             10109.25    2535.41
# American Indian and Alaska Native counts percent         0.01       0.00
# American Indian and Alaska Native moe                 1437.20     571.60
# American Indian and Alaska Native moa percent            0.09       0.14
# Asian counts                                         22101.53    2815.35
# Asian counts percent                                     0.01       0.00
# Asian moe                                             1919.11     709.31
# Asian moa percent                                        0.05       0.15
# Native Hawaiian and Other Pacific Islander counts     3412.20     424.63
# Native Hawaiian and Other Pacific Islander coun...       0.00       0.00
# Native Hawaiian and Other Pacific Islander moe         867.40     213.56
# Native Hawaiian and Other Pacific Islander moa ...       0.15       0.31
# Some other race counts                               87900.40   38234.41
# Some other race counts percent                           0.05       0.02
# Some other race moe                                   5703.81    3217.29
# Some other race moa percent                              0.04       0.05
#
#                                                             2          3  \
# Total population counts                             130625.49  140848.63
# Total population counts percent                          0.07       0.08
# Total population moe                                  4282.35    4040.20
# Total population moa percent                             0.02       0.02
# White counts                                         84315.21  109724.27
# White counts percent                                     0.05       0.06
# White moe                                             3887.29    3803.39
# White moa percent                                        0.03       0.02
# Black or African American counts                     30883.94    6660.39
# Black or African American counts percent                 0.02       0.00
# Black or African American moe                         2290.09    1040.73
# Black or African American moa percent                    0.05       0.09
# American Indian and Alaska Native counts              2413.08    2624.23
# American Indian and Alaska Native counts percent         0.00       0.00
# American Indian and Alaska Native moe                  626.00     652.02
# American Indian and Alaska Native moa percent            0.16       0.15
# Asian counts                                          2676.88    1493.93
# Asian counts percent                                     0.00       0.00
# Asian moe                                              495.21     576.80
# Asian moa percent                                        0.11       0.23
# Native Hawaiian and Other Pacific Islander counts      563.11      78.28
# Native Hawaiian and Other Pacific Islander coun...       0.00       0.00
# Native Hawaiian and Other Pacific Islander moe         250.64      92.54
# Native Hawaiian and Other Pacific Islander moa ...       0.27       0.72
# Some other race counts                               29945.63   41301.42
# Some other race counts percent                           0.02       0.02
# Some other race moe                                   3088.86    3181.94
# Some other race moa percent                              0.06       0.05
#
#                                                             4          5  \
# Total population counts                             132734.78  141064.66
# Total population counts percent                          0.07       0.08
# Total population moe                                  4164.93    4677.30
# Total population moa percent                             0.02       0.02
# White counts                                        105008.08  123211.69
# White counts percent                                     0.06       0.07
# White moe                                             4207.41    4575.62
# White moa percent                                        0.02       0.02
# Black or African American counts                      7427.99    3832.17
# Black or African American counts percent                 0.00       0.00
# Black or African American moe                          917.39     891.69
# Black or African American moa percent                    0.08       0.14
# American Indian and Alaska Native counts              2721.15    2511.07
# American Indian and Alaska Native counts percent         0.00       0.00
# American Indian and Alaska Native moe                  680.55     660.50
# American Indian and Alaska Native moa percent            0.15       0.16
# Asian counts                                          2091.02     422.88
# Asian counts percent                                     0.00       0.00
# Asian moe                                              721.88     175.95
# Asian moa percent                                        0.21       0.25
# Native Hawaiian and Other Pacific Islander counts      230.49     127.03
# Native Hawaiian and Other Pacific Islander coun...       0.00       0.00
# Native Hawaiian and Other Pacific Islander moe         129.60     127.92
# Native Hawaiian and Other Pacific Islander moa ...       0.34       0.61
# Some other race counts                               35107.71   42101.04
# Some other race counts percent                           0.02       0.02
# Some other race moe                                   3069.38    3601.38
# Some other race moa percent                              0.05       0.05
#
#                                                             6          7  \
# Total population counts                             129776.89  152535.62
# Total population counts percent                          0.07       0.08
# Total population moe                                  4401.06    4572.60
# Total population moa percent                             0.02       0.02
# White counts                                        110177.31  126566.09
# White counts percent                                     0.06       0.07
# White moe                                             4415.60    4196.36
# White moa percent                                        0.02       0.02
# Black or African American counts                     10791.83   10956.99
# Black or African American counts percent                 0.01       0.01
# Black or African American moe                         1711.33    1989.28
# Black or African American moa percent                    0.10       0.11
# American Indian and Alaska Native counts              3206.19    3074.87
# American Indian and Alaska Native counts percent         0.00       0.00
# American Indian and Alaska Native moe                  708.01     593.74
# American Indian and Alaska Native moa percent            0.13       0.12
# Asian counts                                          4797.91    7110.69
# Asian counts percent                                     0.00       0.00
# Asian moe                                              925.43    1061.71
# Asian moa percent                                        0.12       0.09
# Native Hawaiian and Other Pacific Islander counts      733.95     610.21
# Native Hawaiian and Other Pacific Islander coun...       0.00       0.00
# Native Hawaiian and Other Pacific Islander moe         452.39     323.41
# Native Hawaiian and Other Pacific Islander moa ...       0.37       0.32
# Some other race counts                               30842.87   34779.89
# Some other race counts percent                           0.02       0.02
# Some other race moe                                   3547.56    3021.40
# Some other race moa percent                              0.07       0.05
#
#                                                             8          9  \
# Total population counts                             145193.17  120314.07
# Total population counts percent                          0.08       0.06
# Total population moe                                  3805.53    3340.46
# Total population moa percent                             0.02       0.02
# White counts                                        110726.58  101038.56
# White counts percent                                     0.06       0.05
# White moe                                             3579.12    3154.69
# White moa percent                                        0.02       0.02
# Black or African American counts                     12039.31    8175.25
# Black or African American counts percent                 0.01       0.00
# Black or African American moe                         1411.35    1091.79
# Black or African American moa percent                    0.07       0.08
# American Indian and Alaska Native counts              2634.96    1796.89
# American Indian and Alaska Native counts percent         0.00       0.00
# American Indian and Alaska Native moe                  579.46     378.63
# American Indian and Alaska Native moa percent            0.13       0.13
# Asian counts                                         16730.39    8354.91
# Asian counts percent                                     0.01       0.00
# Asian moe                                             1849.65    1162.09
# Asian moa percent                                        0.07       0.08
# Native Hawaiian and Other Pacific Islander counts      350.92     378.16
# Native Hawaiian and Other Pacific Islander coun...       0.00       0.00
# Native Hawaiian and Other Pacific Islander moe         169.36     182.14
# Native Hawaiian and Other Pacific Islander moa ...       0.29       0.29
# Some other race counts                               25943.55   19696.78
# Some other race counts percent                           0.01       0.01
# Some other race moe                                   2420.00    2369.77
# Some other race moa percent                              0.06       0.07
#
#                                                            10
# Total population counts                             141125.95
# Total population counts percent                          0.08
# Total population moe                                  3831.35
# Not Hispanic or Latino!!Native Hawaiian and Oth...       0.31      0.45
# Not Hispanic or Latino!!Some other race alone c...    1885.34    301.31
# Not Hispanic or Latino!!Some other race alone c...       0.00      0.00
# Not Hispanic or Latino!!Some other race alone moe      869.60    157.95
# Not Hispanic or Latino!!Some other race alone m...       0.28      0.32
# Not Hispanic or Latino!!Two or more races counts     14383.98   1590.82
# Not Hispanic or Latino!!Two or more races count...       0.02      0.00
# Not Hispanic or Latino!!Two or more races moe         1456.11    365.71
# Not Hispanic or Latino!!Two or more races moa p...       0.06      0.14
# Not Hispanic or Latino!!Two or more races!!Two ...     679.92    464.53
# Not Hispanic or Latino!!Two or more races!!Two ...       0.00      0.00
# Not Hispanic or Latino!!Two or more races!!Two ...     265.46    243.43
# Not Hispanic or Latino!!Two or more races!!Two ...       0.24      0.32
# Not Hispanic or Latino!!Two or more races!!Two ...   13704.06   1126.30
# Not Hispanic or Latino!!Two or more races!!Two ...       0.02      0.00
# Not Hispanic or Latino!!Two or more races!!Two ...    1423.22    284.01
# Not Hispanic or Latino!!Two or more races!!Two ...       0.06      0.15
#
#                                                            2         3  \
# Not Hispanic or Latino counts                       54362.54  24464.72
# Not Hispanic or Latino counts percent                   0.08      0.03
# Not Hispanic or Latino moe                           2756.55   1850.89
# Not Hispanic or Latino moa percent                      0.03      0.05
# Not Hispanic or Latino!!White alone counts          23186.23  16718.65
# Not Hispanic or Latino!!White alone counts percent      0.03      0.02
# Not Hispanic or Latino!!White alone moe              1746.09   1478.45
# Not Hispanic or Latino!!White alone moa percent         0.05      0.05
# Not Hispanic or Latino!!Black or African Americ...  25784.93   5204.54
# Not Hispanic or Latino!!Black or African Americ...      0.04      0.01
# Not Hispanic or Latino!!Black or African Americ...   2133.02    920.77
# Not Hispanic or Latino!!Black or African Americ...      0.05      0.11
# Not Hispanic or Latino!!American Indian and Ala...    241.33    148.75
# Not Hispanic or Latino!!American Indian and Ala...      0.00      0.00
# Not Hispanic or Latino!!American Indian and Ala...    212.74    127.47
# Not Hispanic or Latino!!American Indian and Ala...      0.54      0.52
# Not Hispanic or Latino!!Asian alone counts           1884.56   1095.57
# Not Hispanic or Latino!!Asian alone counts percent      0.00      0.00
# Not Hispanic or Latino!!Asian alone moe               446.71    551.39
# Not Hispanic or Latino!!Asian alone moa percent         0.14      0.31
# Not Hispanic or Latino!!Native Hawaiian and Oth...    208.16     12.15
# Not Hispanic or Latino!!Native Hawaiian and Oth...      0.00      0.00
# Not Hispanic or Latino!!Native Hawaiian and Oth...    206.18     84.54
# Not Hispanic or Latino!!Native Hawaiian and Oth...      0.60      4.23
# Not Hispanic or Latino!!Some other race alone c...    377.86    318.55
# Not Hispanic or Latino!!Some other race alone c...      0.00      0.00
# Not Hispanic or Latino!!Some other race alone moe     203.12    230.56
# Not Hispanic or Latino!!Some other race alone m...      0.33      0.44
# Not Hispanic or Latino!!Two or more races counts     2679.47    966.51
# Not Hispanic or Latino!!Two or more races count...      0.00      0.00
# Not Hispanic or Latino!!Two or more races moe         563.59    332.71
# Not Hispanic or Latino!!Two or more races moa p...      0.13      0.21
# Not Hispanic or Latino!!Two or more races!!Two ...    410.25    118.36
# Not Hispanic or Latino!!Two or more races!!Two ...      0.00      0.00
# Not Hispanic or Latino!!Two or more races!!Two ...    220.68     96.43
# Not Hispanic or Latino!!Two or more races!!Two ...      0.33      0.50
# Not Hispanic or Latino!!Two or more races!!Two ...   2269.23    848.15
# Not Hispanic or Latino!!Two or more races!!Two ...      0.00      0.00
# Not Hispanic or Latino!!Two or more races!!Two ...
00
# Not Hispanic or Latino!!Native Hawaiian and Oth...      0.00      0.00
# Not Hispanic or Latino!!Native Hawaiian and Oth...    178.57    241.45
# Not Hispanic or Latino!!Native Hawaiian and Oth...      0.64      0.46
# Not Hispanic or Latino!!Some other race alone c...    154.23    275.33
# Not Hispanic or Latino!!Some other race alone c...      0.00      0.00
# Not Hispanic or Latino!!Some other race alone moe     113.34    184.22
# Not Hispanic or Latino!!Some other race alone m...      0.45      0.41
# Not Hispanic or Latino!!Two or more races counts     3353.98   2558.70
# Not Hispanic or Latino!!Two or more races count...      0.00      0.00
# Not Hispanic or Latino!!Two or more races moe        1028.05    598.79
# Not Hispanic or Latino!!Two or more races moa p...      0.19      0.14
# Not Hispanic or Latino!!Two or more races!!Two ...    203.04    468.64
# Not Hispanic or Latino!!Two or more races!!Two ...      0.00      0.00
# Not Hispanic or Latino!!Two or more races!!Two ...    173.55    400.36
# Not Hispanic or Latino!!Two or more races!!Two ...      0.52      0.52
# Not Hispanic or Latino!!Two or more races!!Two ...   3150.94   2090.05
# Not Hispanic or Latino!!Two or more races!!Two ...      0.00      0.00
# Not Hispanic or Latino!!Two or more races!!Two ...   1013.97    447.41
# Not Hispanic or Latino!!Two or more races!!Two ...      0.20      0.13
#
#                                                            8         9  \
# Not Hispanic or Latino counts                       75113.14  72307.87
# Not Hispanic or Latino counts percent                   0.11      0.10
# Not Hispanic or Latino moe                           2886.60   2332.26
# Not Hispanic or Latino moa percent                      0.02      0.02
# Not Hispanic or Latino!!White alone counts          47112.23  56090.23
# Not Hispanic or Latino!!White alone counts percent      0.07      0.08
# Not Hispanic or Latino!!White alone moe              2134.30   1945.80
# Not Hispanic or Latino!!White alone moa percent         0.03      0.02
# Not Hispanic or Latino!!Black or African Americ...   9133.46   5047.22
# Not Hispanic or Latino!!Black or African Americ...      0.01      0.01
# Not Hispanic or Latino!!Black or African Americ...   1261.55    847.56
# Not Hispanic or Latino!!Black or African Americ...      0.08      0.10
# Not Hispanic or Latino!!American Indian and Ala...    297.93     39.22
# Not Hispanic or Latino!!American Indian and Ala...      0.00      0.00
# Not Hispanic or Latino!!American Indian and Ala...    154.25     79.71
# Not Hispanic or Latino!!American Indian and Ala...      0.31      1.24
# Not Hispanic or Latino!!Asian alone counts          14022.12   6159.73
# Not Hispanic or Latino!!Asian alone counts percent      0.02      0.01
# Not Hispanic or Latino!!Asian alone moe              1744.36    998.85
# Not Hispanic or Latino!!Asian alone moa percent         0.08      0.10
# Not Hispanic or Latino!!Native Hawaiian and Oth...     34.65    117.61
# Not Hispanic or Latino!!Native Hawaiian and Oth...      0.00      0.00
# Not Hispanic or Latino!!Native Hawaiian and Oth...     94.19    123.96
# Not Hispanic or Latino!!Native Hawaiian and Oth...      1.65      0.64
# Not Hispanic or Latino!!Some other race alone c...    185.83    777.49
# Not Hispanic or Latino!!Some other race alone c...      0.00      0.00
# Not Hispanic or Latino!!Some other race alone moe     122.32    657.45
# Not Hispanic or Latino!!Some other race alone m...      0.40      0.51
# Not Hispanic or Latino!!Two or more races counts     4326.92   4076.37
# Not Hispanic or Latino!!Two or more races count...      0.01      0.01
# Not Hispanic or Latino!!Two or more races moe         809.87    748.75
# Not Hispanic or Latino!!Two or more races moa p...      0.11      0.11
# Not Hispanic or Latino!!Two or more races!!Two ...    615.33    475.67
# Not Hispanic or Latino!!Two or more races!!Two ...      0.00      0.00
# Not Hispanic or Latino!!Two or more races!!Two ...    338.98    259.43
# Not Hispanic or Latino!!Two or more races!!Two ...      0.33      0.33
# Not Hispanic or Latino!!Two or more races!!Two ...   3711.59   3600.71
# Not Hispanic or Latino!!Two or more races!!Two ...      0.01      0.01
# Not Hispanic or Latino!!Two or more races!!Two ...    732.49    698.98
# Not Hispanic or Latino!!Two or more races!!Two ...      0.12      0.12
#
#                                                           10
# Not Hispanic or Latino counts                       76619.45
# Not Hispanic or Latino counts percent                   0.11
# Not Hispanic or Latino moe                           2756.43
# Not Hispanic or Latino moa percent                      0.02
# Not Hispanic or Latino!!White alone counts          56118.48
# Not Hispanic or Latino!!White alone counts percent      0.08
# Not Hispanic or Latino!!White alone moe              2458.73
# Not Hispanic or Latino!!White alone moa percent         0.03
# Not Hispanic or Latino!!Black or African Americ...  11714.02
# Not Hispanic or Latino!!Black or African Americ...      0.02
# Not Hispanic or Latino!!Black or African Americ...   1346.56
# Not Hispanic or Latino!!Black or African Americ...      0.07
# Not Hispanic or Latino!!American Indian and Ala...    102.82
# Not Hispanic or Latino!!American Indian and Ala...      0.00
# Not Hispanic or Latino!!American Indian and Ala...    100.59
# Not Hispanic or Latino!!American Indian and Ala...      0.59
# Not Hispanic or Latino!!Asian alone counts           3978.32
# Not Hispanic or Latino!!Asian alone counts percent      0.01
# Not Hispanic or Latino!!Asian alone moe               681.28
# Not Hispanic or Latino!!Asian alone moa percent         0.10
# Not Hispanic or Latino!!Native Hawaiian and Oth...    119.15
# Not Hispanic or Latino!!Native Hawaiian and Oth...      0.00
# Not Hispanic or Latino!!Native Hawaiian and Oth...    128.68
# Not Hispanic or Latino!!Native Hawaiian and Oth...      0.66
# Not Hispanic or Latino!!Some other race alone c...    434.24
# Not Hispanic or Latino!!Some other race alone c...      0.00
# Not Hispanic or Latino!!Some other race alone moe     347.36
# Not Hispanic or Latino!!Some other race alone m...      0.49
# Not Hispanic or Latino!!Two or more races counts     4152.42
# Not Hispanic or Latino!!Two or more races count...      0.01
# Not Hispanic or Latino!!Two or more races moe         798.91
# Not Hispanic or Latino!!Two or more races moa p...      0.12
# Not Hispanic or Latino!!Two or more races!!Two ...    635.25
# Not Hispanic or Latino!!Two or more races!!Two ...      0.00
# Not Hispanic or Latino!!Two or more races!!Two ...    344.14
# Not Hispanic or Latino!!Two or more races!!Two ...      0.33
# Not Hispanic or Latino!!Two or more races!!Two ...   3517.17
# Not Hispanic or Latino!!Two or more races!!Two ...      0.00
# Not Hispanic or Latino!!Two or more races!!Two ...    726.80
# Not Hispanic or Latino!!Two or more races!!Two ...      0.13

# %% [markdown]
# ### Housing Units

# %%
grouping = groups[4]
print(grouping)
print()

current_labels = labels [labels.label.str.contains(grouping)]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
    
final6 = cal_district_numbers(dist, dataall, labels, labels_check, 'DP05_0086E')
final6
# Out:
# Total housing units
#
# Estimate!!Total housing units
#                                             0         1         2         3  \
# Total housing units counts          169004.87  62543.29  51190.97  53805.84
# Total housing units counts percent       0.23      0.09      0.07      0.07
# Total housing units moe               2357.91   1418.24   1164.17   1189.01
# Total housing units moa percent          0.01      0.01      0.01      0.01
#
#                                            4         5         6         7  \
# Total housing units counts          43728.79  51617.79  46648.37  63340.62
# Total housing units counts percent      0.06      0.07      0.06      0.09
# Total housing units moe               939.73   1208.81   1182.50   1426.58
# Total housing units moa percent         0.01      0.01      0.02      0.01
#
#                                            8         9        10
# Total housing units counts          68283.71  54064.33  58664.41
# Total housing units counts percent      0.09      0.07      0.08
# Total housing units moe              1404.72   1189.99   1151.38
# Total housing units moa percent         0.01      0.01      0.01

# %% [markdown]
# ### Citizen, Voting Age

# %%
grouping = groups[5]
print(grouping)
print()

current_labels = labels [labels.label.str.contains(grouping)]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
    
final7 = cal_district_numbers(dist, dataall, labels, labels_check, 'DP05_0087E')
final7
# Out:
# CITIZEN, VOTING AGE POPULATION
#
# Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population
# Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!Male
# Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!Female
#                                                         0         1         2  \
# Citizen, 18 and over population counts          329936.39  93199.18  84577.51
# Citizen, 18 and over population counts percent       0.26      0.07      0.07
# Citizen, 18 and over population moe               6243.25   2803.03   2903.50
# Citizen, 18 and over population moa percent          0.01      0.02      0.02
# Male counts                                     163395.52  43929.39  40479.47
# Male counts percent                                  0.13      0.03      0.03
# Male moe                                          3913.18   1670.49   1712.44
# Male moa percent                                     0.01      0.02      0.03
# Female counts                                   166540.87  49269.79  44098.04
# Female counts percent                                0.13      0.04      0.04
# Female moe                                        3671.67   1844.96   1754.03
# Female moa percent                                   0.01      0.02      0.02
#
#                                                        3         4         5  \
# Citizen, 18 and over population counts          93468.52  82157.35  85127.68
# Citizen, 18 and over population counts percent      0.07      0.07      0.07
# Citizen, 18 and over population moe              2838.71   2570.36   3049.32
# Citizen, 18 and over population moa percent         0.02      0.02      0.02
# Male counts                                     45602.63  39127.92  41675.92
# Male counts percent                                 0.04      0.03      0.03
# Male moe                                         1826.92   1547.36   2205.46
# Male moa percent                                    0.02      0.02      0.03
# Female counts                                   47865.89  43029.43  43451.75
# Female counts percent                               0.04      0.03      0.03
# Female moe                                       1593.63   1565.29   1603.46
# Female moa percent                                  0.02      0.02      0.02
#
#                                                        6          7  \
# Citizen, 18 and over population counts          88543.40  108491.83
# Citizen, 18 and over population counts percent      0.07       0.09
# Citizen, 18 and over population moe              2838.20    3069.34
# Citizen, 18 and over population moa percent         0.02       0.02
# Male counts                                     42727.34   52202.50
# Male counts percent                                 0.03       0.04
# Male moe                                         1809.97    1966.68
# Male moa percent                                    0.03       0.02
# Female counts                                   45816.06   56289.33
# Female counts percent                               0.04       0.04
# Female moe                                       1742.41    1828.85
# Female moa percent                                  0.02       0.02
#
#                                                         8         9         10
# Citizen, 18 and over population counts          103530.04  86383.81  101280.29
# Citizen, 18 and over population counts percent       0.08      0.07       0.08
# Citizen, 18 and over population moe               2833.10   2378.62    2518.59
# Citizen, 18 and over population moa percent          0.02      0.02       0.02
# Male counts                                      50858.14  41595.66   48791.50
# Male counts percent                                  0.04      0.03       0.04
# Male moe                                          1937.66   1430.00    1570.43
# Male moa percent                                     0.02      0.02       0.02
# Female counts                                    52671.91  44788.15   52488.79
# Female counts percent                                0.04      0.04       0.04
# Female moe                                        1853.89   1594.52    1614.97
# Female moa percent                                   0.02      0.02       0.02

# %%
with pd.ExcelWriter('sa2020_ccd_demo_update.xlsx') as writer:
    final1.to_excel(writer, sheet_name=groups[0][:30])
    final2.to_excel(writer, sheet_name=groups[1][:30])
    final3.to_excel(writer, sheet_name=groups[2][:30])
    final4.to_excel(writer, sheet_name='HISPANIC OR LATINO')
    final5.to_excel(writer, sheet_name='NOT HISPANIC OR LATINO')
    final6.to_excel(writer, sheet_name=groups[4][:30])
    final7.to_excel(writer, sheet_name=groups[5][:30])
