# %% [markdown]
# # Census Data for San Antonio Districts

# %%
import pandas as pd
import numpy as np
import os
import re
import math

# %% [markdown]
# ## District Data

# %% [markdown]
# This sheet tells which district each census tract aligns with and what percentage of the district is included. District 0 are census tracts outside of San Antonio.

# %%
dist = pd.read_excel('CMO_CDTractsPrecincts_220406.xlsx')
dist = dist[['Council District',
             'Tract 2020 ID\n(Use with 2020 Decennial Census)',
             'Percentage of Tract 2020 in Council District']]
dist.columns = ['council','tract','percent']
dist = dist.iloc[1:].reset_index(drop=True)
dist.tract = dist.tract.astype(str)
dist.council = np.where(dist.council == 'Outside CoSA', 0, dist.council)
dist.head()
# Out:
#   council   tract   percent
# 0       1  110100  0.999534
# 1       1  110300  0.499153
# 2       1  110500  0.000150
# 3       1  110600  0.002611
# 4       1  110700  0.953113

# %% [markdown]
# ## Census Data

# %% [markdown]
# This is all the data pulled from the census.

# %%
filename = 'ACSDP5Y2021.DP05-Data.csv'
filename2 = 'ACSDP5Y2021.DP05-Column-Metadata.csv'

# %%
dataall = pd.read_csv(filename)
dataall.columns = dataall.columns.str.lower()

dataall = dataall.iloc[1:].reset_index(drop=True)
# dataall = dataall.replace('(X)', np.nan).replace('-',np.nan).replace('**',np.nan)
# dataall = dataall.dropna(axis=1, how='all')

dataall.geo_id = dataall.geo_id.str[-6:]
dataall.geo_id = dataall.geo_id.astype(str)
dataall = dataall.drop(columns='name')

dataall.head()
# Out:
#    geo_id                                    name dp05_0001e dp05_0001ea  \
# 0  110100  Census Tract 1101, Bexar County, Texas       2934         NaN
# 1  110300  Census Tract 1103, Bexar County, Texas       2930         NaN
# 2  110500  Census Tract 1105, Bexar County, Texas       2201         NaN
# 3  110600  Census Tract 1106, Bexar County, Texas       5384         NaN
# 4  110700  Census Tract 1107, Bexar County, Texas        982         NaN
#
#   dp05_0001m dp05_0001ma dp05_0002e dp05_0002m dp05_0002ma dp05_0002ea  ...  \
# 0        565         NaN       1698        365         NaN         NaN  ...
# 1        652         NaN       1444        456         NaN         NaN  ...
# 2        309         NaN       1030        198         NaN         NaN  ...
# 3       1620         NaN       4117       1585         NaN         NaN  ...
# 4        246         NaN        525        148         NaN         NaN  ...
#
#   dp05_0087pea dp05_0088pe dp05_0088pm dp05_0088pma dp05_0088pea dp05_0089pe  \
# 0          NaN        53.2         8.7          NaN          NaN        46.8
# 1          NaN        49.8         6.8          NaN          NaN        50.2
# 2          NaN        39.2         6.8          NaN          NaN        60.8
# 3          NaN        77.6         8.5          NaN          NaN        22.4
# 4          NaN        52.8         6.9          NaN          NaN        47.2
#
#   dp05_0089pm dp05_0089pma dp05_0089pea unnamed: 714
# 0         8.7          NaN          NaN          NaN
# 1         6.8          NaN          NaN          NaN
# 2         6.8          NaN          NaN          NaN
# 3         8.5          NaN          NaN          NaN
# 4         6.9          NaN          NaN          NaN
#
# [5 rows x 715 columns]

# %% [markdown]
# ## Labels

# %% [markdown]
# These are the labels for the census data.

# %%
labels = pd.read_csv(filename2)
labels.columns = labels.columns.str.lower().str.replace('\W+','_', regex=True)
labels.column_name = labels.column_name.str.lower()

labels = labels [labels.label.str.startswith('Estimate')]
labels = labels [~labels.label.str.contains('ratio')]

groups = labels.label.str.split('!', expand=True)[2].unique()
groups
# Out:
# array(['SEX AND AGE', 'RACE',
#        'Race alone or in combination with one or more other races',
#        'HISPANIC OR LATINO AND RACE', 'Total housing units',
#        'CITIZEN, VOTING AGE POPULATION'], dtype=object)

# %% [markdown]
# ## Functions to combine everything

# %%
def cal_counts(label):
    #pull out estimate and moa
    name_est = label + 'e'
    name_moa = label + 'm'

    #find the corresponding title to census label
    string = labels [labels.column_name == name_est].label.iloc[0]
#     label_title = re.findall('!!([\w\s]+)$',string)[0]
    if not string.split('!!')[3:]:
        label_title = string.split('!!')[-1]
    else:
        label_title = '!!'.join(string.split('!!')[3:])

    #isolate just one indicator
    data = dataall[['geo_id', name_est, name_moa]].copy()

    #join districts and indicator together
    df = dist.merge(data, how='inner', right_on='geo_id', left_on='tract')
    df = df.replace(np.nan, 0)

    #get count percentages for each census tract per district
    df['tru_count'] = df[name_est].astype(float) * df.percent
    df['tru_error'] = df[name_moa].astype(float) * df.percent

    #for each council district, sum up counts, and calculate new moe
    council_counts = []
    total_counts = df.tru_count.sum()

    for x in df.council.unique():
        subset = df [df.council == x]

        count = round(subset.tru_count.sum(), 2)
        count_perc = round(count / total_counts, 2)

        error = round((subset.tru_error ** 2).sum()**.5, 2)
        error_perc = round(math.sqrt(sum((subset.tru_error / 1.645)**2)) / count, 2)

        council_counts.append([x, count, count_perc, error, error_perc])

    #convert to dataframe and format
    dff = pd.DataFrame(council_counts).sort_values(0)
    dff.columns = [label_title, 'counts', 'count_perc', 'moe', 'moe_perc']
    dff = dff.set_index(label_title, drop=True)
#     print(dff)

    return dff

# %%
def cal_district_numbers(labels_check):
    district_totals = pd.DataFrame(np.arange(11))
    totals = []

    for label in labels_check:
        dff = cal_counts(label)
        name = dff.index.name
        dff.columns = [name + ' counts', name + ' counts percent', name + ' moe', name + ' moa percent']
        dff = dff.reset_index(drop=True)

        district_totals = pd.concat([district_totals,dff],axis=1)

    district_totals = district_totals.drop(columns=0)
    return district_totals.T

# %% [markdown]
# ## Now calculate!

# %% [markdown]
# ### Total Population

# %%
grouping = groups[0]

current_labels = labels [labels.label.str.contains(grouping)]
current_labels = current_labels.iloc[:1]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
# Out:
# Estimate!!SEX AND AGE!!Total population

# %%
final0 = cal_district_numbers(labels_check)
final0
# Out:
#                                          0          1          2          3  \
# Total population counts          538323.84  125014.68  143060.08  140873.10
# Total population counts percent       0.27       0.06       0.07       0.07
# Total population moe               9093.05    3793.28    4486.09    4040.89
# Total population moa percent          0.01       0.02       0.02       0.02
#
#                                          4          5          6          7  \
# Total population counts          132566.94  125056.03  167877.44  147037.45
# Total population counts percent       0.07       0.06       0.08       0.07
# Total population moe               4164.44    4441.76    5753.03    4444.57
# Total population moa percent          0.02       0.02       0.02       0.02
#
#                                          8          9         10
# Total population counts          166422.74  155155.67  149134.04
# Total population counts percent       0.08       0.08       0.07
# Total population moe               4049.76    4723.08    3877.11
# Total population moa percent          0.01       0.02       0.02

# %% [markdown]
# ### Sex and Age

# %%
grouping = groups[0]

current_labels = labels [labels.label.str.contains(grouping)]
current_labels = current_labels.iloc[1:]
current_labels = current_labels.iloc[:-13]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
# Out:
# Estimate!!SEX AND AGE!!Total population!!Male
# Estimate!!SEX AND AGE!!Total population!!Female
# Estimate!!SEX AND AGE!!Total population!!Under 5 years
# Estimate!!SEX AND AGE!!Total population!!5 to 9 years
# Estimate!!SEX AND AGE!!Total population!!10 to 14 years
# Estimate!!SEX AND AGE!!Total population!!15 to 19 years
# Estimate!!SEX AND AGE!!Total population!!20 to 24 years
# Estimate!!SEX AND AGE!!Total population!!25 to 34 years
# Estimate!!SEX AND AGE!!Total population!!35 to 44 years
# Estimate!!SEX AND AGE!!Total population!!45 to 54 years
# Estimate!!SEX AND AGE!!Total population!!55 to 59 years
# Estimate!!SEX AND AGE!!Total population!!60 to 64 years
# Estimate!!SEX AND AGE!!Total population!!65 to 74 years
# Estimate!!SEX AND AGE!!Total population!!75 to 84 years
# Estimate!!SEX AND AGE!!Total population!!85 years and over

# %%
final1 = cal_district_numbers(labels_check)
final1
# Out:
#                                           0         1         2         3  \
# Male counts                       269224.97  60939.87  71401.00  70799.65
# Male counts percent                    0.27      0.06      0.07      0.07
# Male moe                            5418.28   2149.34   2609.73   2556.41
# Male moa percent                       0.01      0.02      0.02      0.02
# Female counts                     269098.87  64074.81  71659.08  70073.46
# Female counts percent                  0.27      0.06      0.07      0.07
# Female moe                          5298.00   2404.66   2629.87   2228.66
# Female moa percent                     0.01      0.02      0.02      0.02
# Under 5 years counts               38539.69   7610.08  11313.28   9199.65
# Under 5 years counts percent           0.28      0.06      0.08      0.07
# Under 5 years moe                   1942.95    833.16   1152.38    908.59
# Under 5 years moa percent              0.03      0.07      0.06      0.06
# 5 to 9 years counts                41741.04   6532.42  10814.46  10761.00
# 5 to 9 years counts percent            0.30      0.05      0.08      0.08
# 5 to 9 years moe                    2105.13    664.60   1034.28    886.66
# 5 to 9 years moa percent               0.03      0.06      0.06      0.05
# 10 to 14 years counts              45052.51   7112.41  10243.89  10797.20
# 10 to 14 years counts percent          0.31      0.05      0.07      0.07
# 10 to 14 years moe                  2133.66    789.16    917.71    905.99
# 10 to 14 years moa percent             0.03      0.07      0.05      0.05
# 15 to 19 years counts              40880.05   9481.00  10701.93   9428.56
# 15 to 19 years counts percent          0.28      0.07      0.07      0.07
# 15 to 19 years moe                  2325.57   1016.32   1008.29    767.35
# 15 to 19 years moa percent             0.03      0.07      0.06      0.05
# 20 to 24 years counts              32639.84  10033.40  10300.75  10102.55
# 20 to 24 years counts percent          0.23      0.07      0.07      0.07
# 20 to 24 years moe                  2273.95    964.13    959.87    999.05
# 20 to 24 years moa percent             0.04      0.06      0.06      0.06
# 25 to 34 years counts              78828.32  20331.56  23329.81  20502.20
# 25 to 34 years counts percent          0.25      0.06      0.07      0.07
# 25 to 34 years moe                  2991.82   1354.94   1512.38   1474.27
# 25 to 34 years moa percent             0.02      0.04      0.04      0.04
# 35 to 44 years counts              78985.77  16627.24  18600.97  17646.45
# 35 to 44 years counts percent          0.29      0.06      0.07      0.06
# 35 to 44 years moe                  2830.23   1234.05   1339.55   1177.74
# 35 to 44 years moa percent             0.02      0.05      0.04      0.04
# 45 to 54 years counts              67277.03  15935.71  15981.07  16377.69
# 45 to 54 years counts percent          0.28      0.07      0.07      0.07
# 45 to 54 years moe                  2459.89   1242.28   1129.85   1004.04
# 45 to 54 years moa percent             0.02      0.05      0.04      0.04
# 55 to 59 years counts              30687.01   7885.17   9101.72   9307.67
# 55 to 59 years counts percent          0.27      0.07      0.08      0.08
# 55 to 59 years moe                  1575.98    773.05    934.33    809.66
# 55 to 59 years moa percent             0.03      0.06      0.06      0.05
# 60 to 64 years counts              24903.51   6186.18   7336.18   8007.85
# 60 to 64 years counts percent          0.26      0.06      0.08      0.08
# 60 to 64 years moe                  1620.70    636.37    783.63    770.88
# 60 to 64 years moa percent             0.04      0.06      0.06      0.06
# 65 to 74 years counts              37657.07   9962.82   9621.38  11540.47
# 65 to 74 years counts percent          0.26      0.07      0.07      0.08
# 65 to 74 years moe                  1665.13    740.97    782.79    884.16
# 65 to 74 years moa percent             0.03      0.05      0.05      0.05
# 75 to 84 years counts              15636.13   4875.83   4228.27   5309.37
# 75 to 84 years counts percent          0.24      0.07      0.06      0.08
# 75 to 84 years moe                   960.35    569.78    431.11    561.12
# 75 to 84 years moa percent             0.04      0.07      0.06      0.06
# 85 years and over counts            5495.86   2440.87   1486.36   1892.45
# 85 years and over counts percent       0.20      0.09      0.05      0.07
# 85 years and over moe                690.83    404.75    233.34    355.55
# 85 years and over moa percent          0.08      0.10      0.10      0.11
#
#                                          4         5         6         7  \
# Male counts                       65484.70  63334.33  82438.15  71437.55
# Male counts percent                   0.07      0.06      0.08      0.07
# Male moe                           2364.47   2863.35   3359.64   2643.22
# Male moa percent                      0.02      0.03      0.02      0.02
# Female counts                     67082.24  61721.70  85439.29  75599.90
# Female counts percent                 0.07      0.06      0.09      0.08
# Female moe                         2492.20   2406.98   3332.97   2515.49
# Female moa percent                    0.02      0.02      0.02      0.02
# Under 5 years counts               9717.95   9483.11  12491.07   9346.64
# Under 5 years counts percent          0.07      0.07      0.09      0.07
# Under 5 years moe                  1068.29    985.98   1520.32    950.76
# Under 5 years moa percent             0.07      0.06      0.07      0.06
# 5 to 9 years counts               11007.56   9887.98  12302.34   9022.37
# 5 to 9 years counts percent           0.08      0.07      0.09      0.06
# 5 to 9 years moe                    936.02    927.77   1181.26    807.20
# 5 to 9 years moa percent              0.05      0.06      0.06      0.05
# 10 to 14 years counts             11578.31   9655.56  12891.77   9844.42
# 10 to 14 years counts percent         0.08      0.07      0.09      0.07
# 10 to 14 years moe                 1011.47    886.11   1149.06   1113.08
# 10 to 14 years moa percent            0.05      0.06      0.05      0.07
# 15 to 19 years counts             11757.93   8470.86  11813.56  10921.39
# 15 to 19 years counts percent         0.08      0.06      0.08      0.08
# 15 to 19 years moe                  999.37    795.47   1229.45   1038.26
# 15 to 19 years moa percent            0.05      0.06      0.06      0.06
# 20 to 24 years counts              9169.13   8561.35  13165.11   9856.60
# 20 to 24 years counts percent         0.06      0.06      0.09      0.07
# 20 to 24 years moe                  914.57    788.96   1255.42   1015.45
# 20 to 24 years moa percent            0.06      0.06      0.06      0.06
# 25 to 34 years counts             18421.35  17637.92  29276.48  24615.00
# 25 to 34 years counts percent         0.06      0.06      0.09      0.08
# 25 to 34 years moe                 1327.33   1385.27   2105.23   1547.22
# 25 to 34 years moa percent            0.04      0.05      0.04      0.04
# 35 to 44 years counts             19006.08  16037.48  23159.07  19486.89
# 35 to 44 years counts percent         0.07      0.06      0.08      0.07
# 35 to 44 years moe                 1271.15   1231.36   1452.59   1461.20
# 35 to 44 years moa percent            0.04      0.05      0.04      0.05
# 45 to 54 years counts             15335.48  13831.41  18693.27  16567.04
# 45 to 54 years counts percent         0.06      0.06      0.08      0.07
# 45 to 54 years moe                 1110.44   1033.16   1305.63    990.01
# 45 to 54 years moa percent            0.04      0.05      0.04      0.04
# 55 to 59 years counts              6719.53   7712.44   9718.92   8469.81
# 55 to 59 years counts percent         0.06      0.07      0.08      0.07
# 55 to 59 years moe                  669.75    758.93    984.84    721.06
# 55 to 59 years moa percent            0.06      0.06      0.06      0.05
# 60 to 64 years counts              5784.82   6595.04   7971.30   7860.38
# 60 to 64 years counts percent         0.06      0.07      0.08      0.08
# 60 to 64 years moe                  555.57    612.08    833.02    762.83
# 60 to 64 years moa percent            0.06      0.06      0.06      0.06
# 65 to 74 years counts              8461.00  10016.92  10963.42  11983.91
# 65 to 74 years counts percent         0.06      0.07      0.07      0.08
# 65 to 74 years moe                  625.07    757.25    979.26    820.38
# 65 to 74 years moa percent            0.04      0.05      0.05      0.04
# 75 to 84 years counts              4206.69   4808.97   4007.55   5668.48
# 75 to 84 years counts percent         0.06      0.07      0.06      0.09
# 75 to 84 years moe                  563.59    442.28    552.57    522.94
# 75 to 84 years moa percent            0.08      0.06      0.08      0.06
# 85 years and over counts           1401.12   2356.97   1423.56   3394.51
# 85 years and over counts percent      0.05      0.09      0.05      0.13
# 85 years and over moe               288.08    405.54    356.83    684.98
# 85 years and over moa percent         0.12      0.10      0.15      0.12
#
#                                          8         9        10
# Male counts                       84107.49  76641.17  71491.14
# Male counts percent                   0.09      0.08      0.07
# Male moe                           2766.16   2934.49   2168.79
# Male moa percent                      0.02      0.02      0.02
# Female counts                     82315.26  78514.50  77642.90
# Female counts percent                 0.08      0.08      0.08
# Female moe                         2434.23   2654.38   2522.20
# Female moa percent                    0.02      0.02      0.02
# Under 5 years counts              10367.40   8217.69   9974.42
# Under 5 years counts percent          0.08      0.06      0.07
# Under 5 years moe                   937.61   1062.86   1016.06
# Under 5 years moa percent             0.05      0.08      0.06
# 5 to 9 years counts                9133.05   9973.90   9594.86
# 5 to 9 years counts percent           0.06      0.07      0.07
# 5 to 9 years moe                    839.13   1092.15    989.54
# 5 to 9 years moa percent              0.06      0.07      0.06
# 10 to 14 years counts              8595.45  10804.05   9333.42
# 10 to 14 years counts percent         0.06      0.07      0.06
# 10 to 14 years moe                  837.84   1004.53    945.98
# 10 to 14 years moa percent            0.06      0.06      0.06
# 15 to 19 years counts             12031.83   9882.09   9472.79
# 15 to 19 years counts percent         0.08      0.07      0.07
# 15 to 19 years moe                 1069.21    880.80    888.14
# 15 to 19 years moa percent            0.05      0.05      0.06
# 20 to 24 years counts             21065.38   8681.47  10316.42
# 20 to 24 years counts percent         0.15      0.06      0.07
# 20 to 24 years moe                 1662.38   1136.82   1077.83
# 20 to 24 years moa percent            0.05      0.08      0.06
# 25 to 34 years counts             33895.49  22530.74  23455.14
# 25 to 34 years counts percent         0.11      0.07      0.07
# 25 to 34 years moe                 1775.91   1522.94   1531.50
# 25 to 34 years moa percent            0.03      0.04      0.04
# 35 to 44 years counts             21019.62  24598.00  21092.43
# 35 to 44 years counts percent         0.08      0.09      0.08
# 35 to 44 years moe                 1320.99   1522.78   1256.99
# 35 to 44 years moa percent            0.04      0.04      0.04
# 45 to 54 years counts             18177.91  21353.76  18826.64
# 45 to 54 years counts percent         0.08      0.09      0.08
# 45 to 54 years moe                 1142.17   1316.21   1090.30
# 45 to 54 years moa percent            0.04      0.04      0.04
# 55 to 59 years counts              7308.33   9188.78   8627.63
# 55 to 59 years counts percent         0.06      0.08      0.08
# 55 to 59 years moe                  707.70    854.60    699.02
# 55 to 59 years moa percent            0.06      0.06      0.05
# 60 to 64 years counts              6991.24   7681.45   7483.03
# 60 to 64 years counts percent         0.07      0.08      0.08
# 60 to 64 years moe                  658.18    641.07    685.80
# 60 to 64 years moa percent            0.06      0.05      0.06
# 65 to 74 years counts             10539.97  13436.40  12608.65
# 65 to 74 years counts percent         0.07      0.09      0.09
# 65 to 74 years moe                  831.62    928.42    725.81
# 65 to 74 years moa percent            0.05      0.04      0.03
# 75 to 84 years counts              5026.89   6647.89   5612.92
# 75 to 84 years counts percent         0.08      0.10      0.09
# 75 to 84 years moe                  532.95    763.68    585.80
# 75 to 84 years moa percent            0.06      0.07      0.06
# 85 years and over counts           2270.17   2159.46   2735.68
# 85 years and over counts percent      0.08      0.08      0.10
# 85 years and over moe               464.81    366.01    459.62
# 85 years and over moa percent         0.12      0.10      0.10

# %% [markdown]
# ### Race

# %%
grouping = groups[1]
print(grouping)

current_labels = labels [labels.label.str.contains(grouping)]
current_labels = current_labels.iloc[1:]
current_labels = current_labels.iloc[:-16]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
# Out:
# RACE
# Estimate!!RACE!!Total population!!One race
# Estimate!!RACE!!Total population!!Two or more races
# Estimate!!RACE!!Total population!!One race
# Estimate!!RACE!!Total population!!One race!!White
# Estimate!!RACE!!Total population!!One race!!Black or African American
# Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native
# Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native!!Cherokee tribal grouping
# Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native!!Chippewa tribal grouping
# Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native!!Navajo tribal grouping
# Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native!!Sioux tribal grouping
# Estimate!!RACE!!Total population!!One race!!Asian
# Estimate!!RACE!!Total population!!One race!!Asian!!Asian Indian
# Estimate!!RACE!!Total population!!One race!!Asian!!Chinese
# Estimate!!RACE!!Total population!!One race!!Asian!!Filipino
# Estimate!!RACE!!Total population!!One race!!Asian!!Japanese
# Estimate!!RACE!!Total population!!One race!!Asian!!Korean
# Estimate!!RACE!!Total population!!One race!!Asian!!Vietnamese
# Estimate!!RACE!!Total population!!One race!!Asian!!Other Asian
# Estimate!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander
# Estimate!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander!!Native Hawaiian
# Estimate!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander!!Chamorro
# Estimate!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander!!Samoan
# Estimate!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander!!Other Pacific Islander
# Estimate!!RACE!!Total population!!One race!!Some other race
# Estimate!!RACE!!Total population!!Two or more races
# Estimate!!RACE!!Total population!!Two or more races!!White and Black or African American
# Estimate!!RACE!!Total population!!Two or more races!!White and American Indian and Alaska Native
# Estimate!!RACE!!Total population!!Two or more races!!White and Asian
# Estimate!!RACE!!Total population!!Two or more races!!Black or African American and American Indian and Alaska Native

# %%
final2 = cal_district_numbers(labels_check)    
final2
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in double_scalars
#                                                             0         1  \
# One race counts                                     456572.04  95274.41
# One race counts percent                                  0.28      0.06
# One race moe                                          8024.58   2944.94
# One race moa percent                                     0.01      0.02
# Two or more races counts                             81751.80  29740.26
# ...                                                       ...       ...
# Two or more races!!White and Asian moa percent           0.10      0.27
# Two or more races!!Black or African American an...     528.29     26.99
# Two or more races!!Black or African American an...       0.39      0.02
# Two or more races!!Black or African American an...     251.62     80.29
# Two or more races!!Black or African American an...       0.29      1.81
#
#                                                             2          3  \
# One race counts                                     122339.36  120482.49
# One race counts percent                                  0.07       0.07
# One race moe                                          3750.48    3824.06
# One race moa percent                                     0.02       0.02
# Two or more races counts                             20720.71   20390.61
# ...                                                       ...        ...
# Two or more races!!White and Asian moa percent           0.29       0.41
# Two or more races!!Black or African American an...     111.54     107.48
# Two or more races!!Black or African American an...       0.08       0.08
# Two or more races!!Black or African American an...      98.27     142.17
# Two or more races!!Black or African American an...       0.54       0.80
#
#                                                             4         5  \
# One race counts                                     113456.78  98391.94
# One race counts percent                                  0.07      0.06
# One race moe                                          3692.82   3469.65
# One race moa percent                                     0.02      0.02
# Two or more races counts                             19110.16  26664.09
# ...                                                       ...       ...
# Two or more races!!White and Asian moa percent           0.32      3.24
# Two or more races!!Black or African American an...      53.26     15.00
# Two or more races!!Black or African American an...       0.04      0.01
# Two or more races!!Black or African American an...      88.41     86.12
# Two or more races!!Black or African American an...       1.01      3.49
#
#                                                             6          7  \
# One race counts                                     132112.92  118362.07
# One race counts percent                                  0.08       0.07
# One race moe                                          4638.05    3745.41
# One race moa percent                                     0.02       0.02
# Two or more races counts                             35764.51   28675.38
# ...                                                       ...        ...
# Two or more races!!White and Asian moa percent           0.18       0.21
# Two or more races!!Black or African American an...     191.12      40.84
# Two or more races!!Black or African American an...       0.14       0.03
# Two or more races!!Black or African American an...     166.35      85.74
# Two or more races!!Black or African American an...       0.53       1.28
#
#                                                             8          9  \
# One race counts                                     141119.77  131732.20
# One race counts percent                                  0.09       0.08
# One race moe                                          3589.11    3938.01
# One race moa percent                                     0.02       0.02
# Two or more races counts                             25302.97   23423.46
# ...                                                       ...        ...
# Two or more races!!White and Asian moa percent           0.17       0.19
# Two or more races!!Black or African American an...      60.91     184.74
# Two or more races!!Black or African American an...       0.05       0.14
# Two or more races!!Black or African American an...     107.72     170.02
# Two or more races!!Black or African American an...       1.08       0.56
#
#                                                            10
# One race counts                                     128582.99
# One race counts percent                                  0.08
# One race moe                                          3501.92
# One race moa percent                                     0.02
# Two or more races counts                             20551.05
# ...                                                       ...
# Two or more races!!White and Asian moa percent           0.19
# Two or more races!!Black or African American an...      25.83
# Two or more races!!Black or African American an...       0.02
# Two or more races!!Black or African American an...      84.82
# Two or more races!!Black or African American an...       2.00
#
# [116 rows x 11 columns]

# %% [markdown]
# ### More Race

# %%
grouping = groups[2]
print(grouping)

current_labels = labels [labels.label.str.contains(grouping)]
current_labels = current_labels.iloc[1:]
# current_labels = current_labels.iloc[:-16]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
# Out:
# Race alone or in combination with one or more other races
# Estimate!!Race alone or in combination with one or more other races!!Total population!!White
# Estimate!!Race alone or in combination with one or more other races!!Total population!!Black or African American
# Estimate!!Race alone or in combination with one or more other races!!Total population!!American Indian and Alaska Native
# Estimate!!Race alone or in combination with one or more other races!!Total population!!Asian
# Estimate!!Race alone or in combination with one or more other races!!Total population!!Native Hawaiian and Other Pacific Islander
# Estimate!!Race alone or in combination with one or more other races!!Total population!!Some other race

# %%
final3 = cal_district_numbers(labels_check)
final3
# Out:
#                                                             0          1  \
# White counts                                        423107.50  109544.86
# White counts percent                                     0.27       0.07
# White moe                                             8757.59    3809.03
# White moa percent                                        0.01       0.02
# Black or African American counts                     66234.65    4295.24
# Black or African American counts percent                 0.36       0.02
# Black or African American moe                         3361.08     700.91
# Black or African American moa percent                    0.03       0.10
# American Indian and Alaska Native counts             10718.60    2612.54
# American Indian and Alaska Native counts percent         0.28       0.07
# American Indian and Alaska Native moe                 1459.93     609.58
# American Indian and Alaska Native moa percent            0.08       0.14
# Asian counts                                         24985.07    2029.46
# Asian counts percent                                     0.31       0.02
# Asian moe                                             2060.34     412.19
# Asian moa percent                                        0.05       0.12
# Native Hawaiian and Other Pacific Islander counts     3572.30     381.69
# Native Hawaiian and Other Pacific Islander coun...       0.46       0.05
# Native Hawaiian and Other Pacific Islander moe         887.53     191.96
# Native Hawaiian and Other Pacific Islander moa ...       0.15       0.31
# Some other race counts                               97190.38   36639.14
# Some other race counts percent                           0.22       0.08
# Some other race moe                                   6069.82    3203.29
# Some other race moa percent                              0.04       0.05
#
#                                                            2          3  \
# White counts                                        94313.67  109738.61
# White counts percent                                    0.06       0.07
# White moe                                            4092.75    3803.89
# White moa percent                                       0.03       0.02
# Black or African American counts                    32491.85    6662.21
# Black or African American counts percent                0.18       0.04
# Black or African American moe                        2385.98    1041.52
# Black or African American moa percent                   0.04       0.10
# American Indian and Alaska Native counts             2721.61    2624.15
# American Indian and Alaska Native counts percent        0.07       0.07
# American Indian and Alaska Native moe                 714.00     652.02
# American Indian and Alaska Native moa percent           0.16       0.15
# Asian counts                                         3213.03    1493.49
# Asian counts percent                                    0.04       0.02
# Asian moe                                             579.20     576.59
# Asian moa percent                                       0.11       0.23
# Native Hawaiian and Other Pacific Islander counts     612.86      78.37
# Native Hawaiian and Other Pacific Islander coun...      0.08       0.01
# Native Hawaiian and Other Pacific Islander moe        258.95      92.58
# Native Hawaiian and Other Pacific Islander moa ...      0.26       0.72
# Some other race counts                              31754.70   41309.68
# Some other race counts percent                          0.07       0.10
# Some other race moe                                  3186.78    3182.10
# Some other race moa percent                             0.06       0.05
#
#                                                             4          5  \
# White counts                                        104863.11  109089.10
# White counts percent                                     0.07       0.07
# White moe                                             4208.40    4322.78
# White moa percent                                        0.02       0.02
# Black or African American counts                      7396.70    3314.27
# Black or African American counts percent                 0.04       0.02
# Black or African American moe                          915.63     858.90
# Black or African American moa percent                    0.08       0.16
# American Indian and Alaska Native counts              2722.30    2197.94
# American Indian and Alaska Native counts percent         0.07       0.06
# American Indian and Alaska Native moe                  681.93     594.98
# American Indian and Alaska Native moa percent            0.15       0.16
# Asian counts                                          2084.17     376.42
# Asian counts percent                                     0.03       0.00
# Asian moe                                              724.21     167.72
# Asian moa percent                                        0.21       0.27
# Native Hawaiian and Other Pacific Islander counts      227.10     105.46
# Native Hawaiian and Other Pacific Islander coun...       0.03       0.01
# Native Hawaiian and Other Pacific Islander moe         129.93     120.43
# Native Hawaiian and Other Pacific Islander moa ...       0.35       0.69
# Some other race counts                               35081.14   37114.96
# Some other race counts percent                           0.08       0.09
# Some other race moe                                   3069.86    3351.79
# Some other race moa percent                              0.05       0.05
#
#                                                             6          7  \
# White counts                                        140467.02  121622.85
# White counts percent                                     0.09       0.08
# White moe                                             5763.56    4009.74
# White moa percent                                        0.02       0.02
# Black or African American counts                     14709.80   10863.63
# Black or African American counts percent                 0.08       0.06
# Black or African American moe                         1915.42    1986.32
# Black or African American moa percent                    0.08       0.11
# American Indian and Alaska Native counts              3729.09    2668.43
# American Indian and Alaska Native counts percent         0.10       0.07
# American Indian and Alaska Native moe                  809.37     525.14
# American Indian and Alaska Native moa percent            0.13       0.12
# Asian counts                                          6773.50    6239.75
# Asian counts percent                                     0.08       0.08
# Asian moe                                             1145.01    1121.43
# Asian moa percent                                        0.10       0.11
# Native Hawaiian and Other Pacific Islander counts      761.70     533.10
# Native Hawaiian and Other Pacific Islander coun...       0.10       0.07
# Native Hawaiian and Other Pacific Islander moe         457.30     306.43
# Native Hawaiian and Other Pacific Islander moa ...       0.36       0.35
# Some other race counts                               39798.93   34977.82
# Some other race counts percent                           0.09       0.08
# Some other race moe                                   4203.89    2945.51
# Some other race moa percent                              0.06       0.05
#
#                                                             8          9  \
# White counts                                        128371.34  131821.82
# White counts percent                                     0.08       0.08
# White moe                                             3859.52    4472.51
# White moa percent                                        0.02       0.02
# Black or African American counts                     13417.52    9943.92
# Black or African American counts percent                 0.07       0.05
# Black or African American moe                         1480.36    1240.83
# Black or African American moa percent                    0.07       0.08
# American Indian and Alaska Native counts              3195.37    2162.37
# American Indian and Alaska Native counts percent         0.08       0.06
# American Indian and Alaska Native moe                  647.88     423.62
# American Indian and Alaska Native moa percent            0.12       0.12
# Asian counts                                         18208.16    9702.91
# Asian counts percent                                     0.22       0.12
# Asian moe                                             1882.34    1279.80
# Asian moa percent                                        0.06       0.08
# Native Hawaiian and Other Pacific Islander counts      437.57     447.06
# Native Hawaiian and Other Pacific Islander coun...       0.06       0.06
# Native Hawaiian and Other Pacific Islander moe         181.90     200.32
# Native Hawaiian and Other Pacific Islander moa ...       0.25       0.27
# Some other race counts                               29456.92   25564.08
# Some other race counts percent                           0.07       0.06
# Some other race moe                                   2588.29    2717.12
# Some other race moa percent                              0.05       0.06
#
#                                                            10
# White counts                                        119569.12
# White counts percent                                     0.08
# White moe                                             3740.14
# White moa percent                                        0.02
# Black or African American counts                     16015.20
# Black or African American counts percent                 0.09
# Black or African American moe                         1599.97
# Black or African American moa percent                    0.06
# American Indian and Alaska Native counts              2815.59
# American Indian and Alaska Native counts percent         0.07
# American Indian and Alaska Native moe                  630.29
# American Indian and Alaska Native moa percent            0.14
# Asian counts                                          6684.03
# Asian counts percent                                     0.08
# Asian moe                                             1004.82
# Asian moa percent                                        0.09
# Native Hawaiian and Other Pacific Islander counts      621.79
# Native Hawaiian and Other Pacific Islander coun...       0.08
# Native Hawaiian and Other Pacific Islander moe         245.49
# Native Hawaiian and Other Pacific Islander moa ...       0.24
# Some other race counts                               25276.26
# Some other race counts percent                           0.06
# Some other race moe                                   2464.68
# Some other race moa percent                              0.06

# %% [markdown]
# ### Hispanic or Latino Race

# %%
grouping = groups[3]
print(grouping)

current_labels = labels [labels.label.str.contains(grouping)]
current_labels = current_labels.iloc[1:]
# current_labels = current_labels.iloc[:-16]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
# Out:
# Hispanic or Latino (of any race)!!Other Hispani...       0.11      0.08
# Hispanic or Latino (of any race)!!Other Hispani...    2336.07   1480.72
# Hispanic or Latino (of any race)!!Other Hispani...       0.09      0.09
# Not Hispanic or Latino counts                        47633.80  50094.78
# Not Hispanic or Latino counts percent                    0.06      0.06
# Not Hispanic or Latino moe                            2727.65   3105.28
# Not Hispanic or Latino moa percent                       0.03      0.04
# Not Hispanic or Latino!!White alone counts           29232.96  33822.12
# Not Hispanic or Latino!!White alone counts percent       0.06      0.06
# Not Hispanic or Latino!!White alone moe               2267.99   2331.92
# Not Hispanic or Latino!!White alone moa percent          0.05      0.04
# Not Hispanic or Latino!!Black or African Americ...    9823.49   8424.66
# Not Hispanic or Latino!!Black or African Americ...       0.07      0.06
# Not Hispanic or Latino!!Black or African Americ...    1183.85   1758.08
# Not Hispanic or Latino!!Black or African Americ...       0.07      0.13
# Not Hispanic or Latino!!American Indian and Ala...     293.66    167.70
# Not Hispanic or Latino!!American Indian and Ala...       0.10      0.06
# Not Hispanic or Latino!!American Indian and Ala...     160.45    114.97
# Not Hispanic or Latino!!American Indian and Ala...       0.33      0.42
# Not Hispanic or Latino!!Asian alone counts            3611.32   5042.74
# Not Hispanic or Latino!!Asian alone counts percent       0.06      0.09
# Not Hispanic or Latino!!Asian alone moe                893.34   1074.73
# Not Hispanic or Latino!!Asian alone moa percent          0.15      0.13
# Not Hispanic or Latino!!Native Hawaiian and Oth...     171.26    275.90
# Not Hispanic or Latino!!Native Hawaiian and Oth...       0.09      0.14
# Not Hispanic or Latino!!Native Hawaiian and Oth...     185.06    220.98
# Not Hispanic or Latino!!Native Hawaiian and Oth...       0.66      0.49
# Not Hispanic or Latino!!Some other race alone c...     313.19    291.96
# Not Hispanic or Latino!!Some other race alone c...       0.06      0.05
# Not Hispanic or Latino!!Some other race alone moe      249.00    182.63
# Not Hispanic or Latino!!Some other race alone m...       0.48      0.38
# Not Hispanic or Latino!!Two or more races counts      4187.92   2069.70
# Not Hispanic or Latino!!Two or more races count...       0.10      0.05
# Not Hispanic or Latino!!Two or more races moe         1081.06    456.68
# Not Hispanic or Latino!!Two or more races moa p...       0.16      0.13
# Not Hispanic or Latino!!Two or more races!!Two ...     267.93    418.70
# Not Hispanic or Latino!!Two or more races!!Two ...       0.06      0.09
# Not Hispanic or Latino!!Two or more races!!Two ...     198.28    277.41
# Not Hispanic or Latino!!Two or more races!!Two ...       0.45      0.40
# Not Hispanic or Latino!!Two or more races!!Two ...    3919.99   1651.00
# Not Hispanic or Latino!!Two or more races!!Two ...       0.10      0.04
# Not Hispanic or Latino!!Two or more races!!Two ...    1065.79    367.64
# Not Hispanic or Latino!!Two or more races!!Two ...       0.17      0.14
#
#                                                            8         9  \
# Hispanic or Latino (of any race) counts             80812.27  65148.44
# Hispanic or Latino (of any race) counts percent         0.07      0.05
# Hispanic or Latino (of any race) moe                 3243.88   3939.98
# Hispanic or Latino (of any race) moa percent            0.02      0.04
# Hispanic or Latino (of any race)!!Mexican counts    67160.08  54654.58
# Hispanic or Latino (of any race)!!Mexican count...      0.06      0.05
# Hispanic or Latino (of any race)!!Mexican moe        3084.04   3904.78
# Hispanic or Latino (of any race)!!Mexican moa p...      0.03      0.04
# Hispanic or Latino (of any race)!!Puerto Rican ...   2147.80   2996.63
# Hispanic or Latino (of any race)!!Puerto Rican ...      0.07      0.10
# Hispanic or Latino (of any race)!!Puerto Rican moe    524.54    767.82
# Hispanic or Latino (of any race)!!Puerto Rican ...      0.15      0.16
# Hispanic or Latino (of any race)!!Cuban counts        843.73    671.57
# Hispanic or Latino (of any race)!!Cuban counts ...      0.13      0.10
# Hispanic or Latino (of any race)!!Cuban moe           536.65    307.79
# Hispanic or Latino (of any race)!!Cuban moa per...      0.39      0.28
# Hispanic or Latino (of any race)!!Other Hispani...  10660.67   6825.66
# Hispanic or Latino (of any race)!!Other Hispani...      0.08      0.05
# Hispanic or Latino (of any race)!!Other Hispani...   1256.92    947.88
# Hispanic or Latino (of any race)!!Other Hispani...      0.07      0.08
# Not Hispanic or Latino counts                       85610.47  90007.23
# Not Hispanic or Latino counts percent                   0.11      0.12
# Not Hispanic or Latino moe                           3025.67   2936.96
# Not Hispanic or Latino moa percent                      0.02      0.02
# Not Hispanic or Latino!!White alone counts          54728.28  70881.06
# Not Hispanic or Latino!!White alone counts percent      0.10      0.13
# Not Hispanic or Latino!!White alone moe              2274.44   2569.92
# Not Hispanic or Latino!!White alone moa percent         0.03      0.02
# Not Hispanic or Latino!!Black or African Americ...  10077.02   6309.92
# Not Hispanic or Latino!!Black or African Americ...      0.07      0.05
# Not Hispanic or Latino!!Black or African Americ...   1292.30    957.20
# Not Hispanic or Latino!!Black or African Americ...      0.08      0.09
# Not Hispanic or Latino!!American Indian and Ala...    310.10    100.26
# Not Hispanic or Latino!!American Indian and Ala...      0.11      0.04
# Not Hispanic or Latino!!American Indian and Ala...    160.07    111.64
# Not Hispanic or Latino!!American Indian and Ala...      0.31      0.68
# Not Hispanic or Latino!!Asian alone counts          15136.92   7024.18
# Not Hispanic or Latino!!Asian alone counts percent      0.26      0.12
# Not Hispanic or Latino!!Asian alone moe              1761.85   1052.08
# Not Hispanic or Latino!!Asian alone moa percent         0.07      0.09
# Not Hispanic or Latino!!Native Hawaiian and Oth...     80.82    124.42
# Not Hispanic or Latino!!Native Hawaiian and Oth...      0.04      0.06
# Not Hispanic or Latino!!Native Hawaiian and Oth...    110.41    132.28
# Not Hispanic or Latino!!Native Hawaiian and Oth...      0.83      0.65
# Not Hispanic or Latino!!Some other race alone c...    201.81    900.95
# Not Hispanic or Latino!!Some other race alone c...      0.04      0.16
# Not Hispanic or Latino!!Some other race alone moe     127.64    665.17
# Not Hispanic or Latino!!Some other race alone m...      0.38      0.45
# Not Hispanic or Latino!!Two or more races counts     5075.52   4666.44
# Not Hispanic or Latino!!Two or more races count...      0.12      0.11
# Not Hispanic or Latino!!Two or more races moe         899.83    800.23
# Not Hispanic or Latino!!Two or more races moa p...      0.11      0.10
# Not Hispanic or Latino!!Two or more races!!Two ...    814.22    545.89
# Not Hispanic or Latino!!Two or more races!!Two ...      0.18      0.12
# Not Hispanic or Latino!!Two or more races!!Two ...    423.00    269.69
# Not Hispanic or Latino!!Two or more races!!Two ...      0.32      0.30
# Not Hispanic or Latino!!Two or more races!!Two ...   4261.30   4120.55
# Not Hispanic or Latino!!Two or more races!!Two ...    344.60
# Not Hispanic or Latino!!Two or more races!!Two ...      0.33
# Not Hispanic or Latino!!Two or more races!!Two ...   3809.25
# Not Hispanic or Latino!!Two or more races!!Two ...      0.10
# Not Hispanic or Latino!!Two or more races!!Two ...    740.74
# Not Hispanic or Latino!!Two or more races!!Two ...      0.12

# %% [markdown]
# ### Housing Units

# %%
grouping = groups[4]
print(grouping)
print()

current_labels = labels [labels.label.str.contains(grouping)]
# current_labels = current_labels.iloc[:-16]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
# Out:
# Total housing units
#
# Estimate!!Total housing units

# %%
final5 = cal_district_numbers(labels_check)
final5
# Out:
#                                             0         1         2         3  \
# Total housing units counts          188661.64  57123.02  57254.27  53818.39
# Total housing units counts percent       0.24      0.07      0.07      0.07
# Total housing units moe               2501.64   1317.08   1360.16   1189.09
# Total housing units moa percent          0.01      0.01      0.01      0.01
#
#                                            4         5         6         7  \
# Total housing units counts          43705.62  45540.96  61319.53  61352.55
# Total housing units counts percent      0.06      0.06      0.08      0.08
# Total housing units moe               939.71   1163.11   1410.20   1362.88
# Total housing units moa percent         0.01      0.02      0.01      0.01
#
#                                            8         9        10
# Total housing units counts          77166.25  69283.60  62837.16
# Total housing units counts percent      0.10      0.09      0.08
# Total housing units moe              1474.12   1445.48   1184.30
# Total housing units moa percent         0.01      0.01      0.01

# %% [markdown]
# ### Citizen, Voting Age

# %%
grouping = groups[5]
print(grouping)

current_labels = labels [labels.label.str.contains(grouping)]
current_labels = current_labels.iloc[:-2]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
# Out:
# CITIZEN, VOTING AGE POPULATION
# Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population

# %%
final6 = cal_district_numbers(labels_check)
final6
# Out:
#                                                         0         1         2  \
# Citizen, 18 and over population counts          365619.97  83863.01  93394.90
# Citizen, 18 and over population counts percent       0.27      0.06      0.07
# Citizen, 18 and over population moe               6535.02   2665.77   3123.29
# Citizen, 18 and over population moa percent          0.01      0.02      0.02
#
#                                                        3         4         5  \
# Citizen, 18 and over population counts          93487.42  81995.24  75691.26
# Citizen, 18 and over population counts percent      0.07      0.06      0.06
# Citizen, 18 and over population moe              2839.13   2569.17   2925.69
# Citizen, 18 and over population moa percent         0.02      0.02      0.02
#
#                                                         6          7  \
# Citizen, 18 and over population counts          113452.60  103135.74
# Citizen, 18 and over population counts percent       0.08       0.08
# Citizen, 18 and over population moe               3633.71    2973.91
# Citizen, 18 and over population moa percent          0.02       0.02
#
#                                                         8          9  \
# Citizen, 18 and over population counts          118668.70  112022.40
# Citizen, 18 and over population counts percent       0.09       0.08
# Citizen, 18 and over population moe               2967.35    3042.50
# Citizen, 18 and over population moa percent          0.02       0.02
#
#                                                        10
# Citizen, 18 and over population counts          107375.75
# Citizen, 18 and over population counts percent       0.08
# Citizen, 18 and over population moe               2552.95
# Citizen, 18 and over population moa percent          0.01

# %%
with pd.ExcelWriter('sa2020_ccd_demo.xlsx') as writer:
    final0.to_excel(writer, sheet_name='Total Population')
    final1.to_excel(writer, sheet_name=groups[0])
    final2.to_excel(writer, sheet_name=groups[1])
    final3.to_excel(writer, sheet_name=groups[2][:30])
    final4.to_excel(writer, sheet_name=groups[3])
    final5.to_excel(writer, sheet_name=groups[4])
    final6.to_excel(writer, sheet_name=groups[5])
