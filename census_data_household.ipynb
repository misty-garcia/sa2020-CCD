# %% [markdown]
# # Census Data for San Antonio Districts

# %%
import pandas as pd
import numpy as np
import os
import re
import math

# %% [markdown]
# ## District Data

# %% [markdown]
# This sheet tells which district each census tract aligns with and what percentage of the district is included. District 0 are census tracts outside of San Antonio.

# %%
dist = pd.read_excel('CMO_CDTractsPrecincts_220406.xlsx')
dist = dist[['Council District',
             'Tract 2020 ID\n(Use with 2020 Decennial Census)',
             'Percentage of Tract 2020 in Council District']]
dist.columns = ['council','tract','percent']
dist = dist.iloc[1:].reset_index(drop=True)
dist.tract = dist.tract.astype(str)
dist.council = np.where(dist.council == 'Outside CoSA', 0, dist.council)
dist.head()
# Out:
#   council   tract   percent
# 0       1  110100  0.999534
# 1       1  110300  0.499153
# 2       1  110500  0.000150
# 3       1  110600  0.002611
# 4       1  110700  0.953113

# %% [markdown]
# ## Census Data

# %% [markdown]
# This is all the data pulled from the census.

# %%
filename = 'ACSDP5Y2021.DP04-Data.csv'
filename2 = 'ACSDP5Y2021.DP04-Column-Metadata.csv'

# %%
dataall = pd.read_csv(filename)
dataall.columns = dataall.columns.str.lower()

dataall = dataall.iloc[1:].reset_index(drop=True)
dataall = dataall.replace('(X)', np.nan).replace('-',np.nan).replace('\*+',np.nan,regex=True)
# dataall = dataall.dropna(axis=1, how='all')

dataall.geo_id = dataall.geo_id.str[-6:]
dataall.geo_id = dataall.geo_id.astype(str)
dataall = dataall.drop(columns='name')

to_fix = []
for col in dataall.columns:
    bad_num = dataall[col].astype(str).str.contains('+',regex=False).sum()
    if bad_num > 0:
        to_fix.append(col)
for col in to_fix:
    dataall[col] = dataall[col].astype(str)\
    .str.replace('+','',regex=False)\
    .str.replace(',','').astype(float)

dataall.head()
# Out:
#    geo_id dp04_0001e  dp04_0001ea dp04_0001m  dp04_0001ma dp04_0002e  \
# 0  110100       2958          NaN        272          NaN       1895
# 1  110300       1888          NaN        265          NaN       1393
# 2  110500       1025          NaN        117          NaN        921
# 3  110600       1637          NaN        255          NaN       1551
# 4  110700        661          NaN        116          NaN        513
#
#   dp04_0002m  dp04_0002ma  dp04_0002ea dp04_0003e  ... dp04_0141pea  \
# 0        286          NaN          NaN       1063  ...          NaN
# 1        251          NaN          NaN        495  ...          NaN
# 2        133          NaN          NaN        104  ...          NaN
# 3        269          NaN          NaN         86  ...          NaN
# 4        104          NaN          NaN        148  ...          NaN
#
#    dp04_0142pe  dp04_0142pm dp04_0142pma dp04_0142pea  dp04_0143pe  \
# 0         31.1         11.4          NaN          NaN          NaN
# 1         40.4         14.5          NaN          NaN          NaN
# 2         41.4         11.7          NaN          NaN          NaN
# 3         51.9         13.9          NaN          NaN          NaN
# 4         43.2         18.6          NaN          NaN          NaN
#
#    dp04_0143pm dp04_0143pma dp04_0143pea  unnamed: 1146
# 0          NaN          NaN          NaN            NaN
# 1          NaN          NaN          NaN            NaN
# 2          NaN          NaN          NaN            NaN
# 3          NaN          NaN          NaN            NaN
# 4          NaN          NaN          NaN            NaN
#
# [5 rows x 1146 columns]

# %% [markdown]
# ## Labels

# %% [markdown]
# These are the labels for the census data.

# %%
labels = pd.read_csv(filename2)
labels.columns = labels.columns.str.lower().str.replace('\W+','_', regex=True)
labels.column_name = labels.column_name.str.lower()

labels = labels [labels.label.str.startswith('Estimate')]
labels = labels [~labels.label.str.contains('ratio')]

groups = labels.label.str.split('!', expand=True)[2].unique()
groups
# Out:
# array(['HOUSING OCCUPANCY', 'UNITS IN STRUCTURE', 'YEAR STRUCTURE BUILT',
#        'ROOMS', 'BEDROOMS', 'HOUSING TENURE',
#        'YEAR HOUSEHOLDER MOVED INTO UNIT', 'VEHICLES AVAILABLE',
#        'HOUSE HEATING FUEL', 'SELECTED CHARACTERISTICS',
#        'OCCUPANTS PER ROOM', 'VALUE', 'MORTGAGE STATUS',
#        'SELECTED MONTHLY OWNER COSTS (SMOC)',
#        'SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)',
#        'GROSS RENT',
#        'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)'],
#       dtype=object)

# %% [markdown]
# ## Functions to combine everything

# %%
def cal_counts(label):
    #pull out estimate and moa
    name_est = label + 'e'
    name_moa = label + 'm'

    #find the corresponding title to census label
    string = labels [labels.column_name == name_est].label.iloc[0]
#     label_title = re.findall('!!([\w\s]+)$',string)[0]
    if not string.split('!!')[3:]:
        label_title = string.split('!!')[-1]
    else:
        label_title = '!!'.join(string.split('!!')[3:])

    #isolate just one indicator
    data = dataall[['geo_id', name_est, name_moa]].copy()

    #join districts and indicator together
    df = dist.merge(data, how='inner', right_on='geo_id', left_on='tract')
    df = df.replace(np.nan, 0)

    #get count percentages for each census tract per district
    df['tru_count'] = df[name_est].astype(float) * df.percent
    df['tru_error'] = df[name_moa].astype(float) * df.percent

    #for each council district, sum up counts, and calculate new moe
    council_counts = []
    total_counts = df.tru_count.sum()

    for x in df.council.unique():
        subset = df [df.council == x]

        count = round(subset.tru_count.sum(), 2)
        count_perc = round(count / total_counts, 2)

        error = round((subset.tru_error ** 2).sum()**.5, 2)
        error_perc = round(math.sqrt(sum((subset.tru_error / 1.645)**2)) / count, 2)

        council_counts.append([x, count, count_perc, error, error_perc])

    #convert to dataframe and format
    dff = pd.DataFrame(council_counts).sort_values(0)
    dff.columns = [label_title, 'counts', 'count_perc', 'moe', 'moe_perc']
    dff = dff.set_index(label_title, drop=True)
#     print(dff)

    return dff

# %%
def cal_district_numbers(labels_check):
    district_totals = pd.DataFrame(np.arange(11))
    totals = []

    for label in labels_check:
        dff = cal_counts(label)
        name = dff.index.name
        dff.columns = [name + ' counts', name + ' counts percent', name + ' moe', name + ' moa percent']
        dff = dff.reset_index(drop=True)

        district_totals = pd.concat([district_totals,dff],axis=1)

    district_totals = district_totals.drop(columns=0)
    return district_totals.T

# %% [markdown]
# ## Now calculate!

# %% [markdown]
# ### Total Housing

# %%
grouping = groups[0]

current_labels = labels [labels.label.str.contains(grouping)]
current_labels = current_labels.iloc[:1]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
# Out:
# Estimate!!HOUSING OCCUPANCY!!Total housing units

# %%
final0 = cal_district_numbers(labels_check)
final0
# Out:
#                                             0         1         2         3  \
# Total housing units counts          188661.64  57123.02  57254.27  53818.39
# Total housing units counts percent       0.24      0.07      0.07      0.07
# Total housing units moe               2501.64   1317.08   1360.16   1189.09
# Total housing units moa percent          0.01      0.01      0.01      0.01
#
#                                            4         5         6         7  \
# Total housing units counts          43705.62  45540.96  61319.53  61352.55
# Total housing units counts percent      0.06      0.06      0.08      0.08
# Total housing units moe               939.71   1163.11   1410.20   1362.88
# Total housing units moa percent         0.01      0.02      0.01      0.01
#
#                                            8         9        10
# Total housing units counts          77166.25  69283.60  62837.16
# Total housing units counts percent      0.10      0.09      0.08
# Total housing units moe              1474.12   1445.48   1184.30
# Total housing units moa percent         0.01      0.01      0.01

# %% [markdown]
# ### Housing units

# %%
grouping = groups[0]
print(grouping)
print()

current_labels = labels [labels.label.str.contains(grouping)]
current_labels = current_labels.iloc[1:]
# current_labels = current_labels.iloc[:-13]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
# Out:
# HOUSING OCCUPANCY
#
# Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units
# Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units
# Estimate!!HOUSING OCCUPANCY!!Total housing units!!Homeowner vacancy rate
# Estimate!!HOUSING OCCUPANCY!!Total housing units!!Rental vacancy rate

# %%
final1 = cal_district_numbers(labels_check)
final1
# Out:
#                                                0         1         2  \
# Occupied housing units counts          177329.79  49774.31  51222.14
# Occupied housing units counts percent       0.25      0.07      0.07
# Occupied housing units moe               2512.64   1355.11   1382.56
# Occupied housing units moa percent          0.01      0.02      0.02
# Vacant housing units counts             11331.85   7348.71   6032.14
# Vacant housing units counts percent         0.19      0.12      0.10
# Vacant housing units moe                  965.12    652.99    567.36
# Vacant housing units moa percent            0.05      0.05      0.06
# Homeowner vacancy rate counts              97.15     51.18     97.71
# Homeowner vacancy rate counts percent       0.18      0.09      0.18
# Homeowner vacancy rate moe                 61.28     56.73    106.79
# Homeowner vacancy rate moa percent          0.38      0.67      0.66
# Rental vacancy rate counts                646.11    242.39    215.59
# Rental vacancy rate counts percent          0.26      0.10      0.09
# Rental vacancy rate moe                   173.47     40.21     40.67
# Rental vacancy rate moa percent             0.16      0.10      0.11
#
#                                               3         4         5         6  \
# Occupied housing units counts          49100.15  40884.53  40961.91  57962.61
# Occupied housing units counts percent      0.07      0.06      0.06      0.08
# Occupied housing units moe              1229.05    990.80   1169.42   1486.44
# Occupied housing units moa percent         0.02      0.01      0.02      0.02
# Vacant housing units counts             4718.24   2821.09   4579.05   3356.92
# Vacant housing units counts percent        0.08      0.05      0.08      0.06
# Vacant housing units moe                 505.92    403.10    469.36    581.22
# Vacant housing units moa percent           0.07      0.09      0.06      0.11
# Homeowner vacancy rate counts             46.58     40.07     38.55     17.96
# Homeowner vacancy rate counts percent      0.09      0.07      0.07      0.03
# Homeowner vacancy rate moe                55.73     24.15     50.53    102.60
# Homeowner vacancy rate moa percent         0.73      0.37      0.80      3.47
# Rental vacancy rate counts               167.26    148.99    100.36    157.13
# Rental vacancy rate counts percent         0.07      0.06      0.04      0.06
# Rental vacancy rate moe                   59.15     52.67     41.10     64.98
# Rental vacancy rate moa percent            0.21      0.21      0.25      0.25
#
#                                               7         8         9        10
# Occupied housing units counts          56476.88  69755.57  64733.36  58922.75
# Occupied housing units counts percent      0.08      0.10      0.09      0.08
# Occupied housing units moe              1416.77   1552.83   1487.35   1194.84
# Occupied housing units moa percent         0.02      0.01      0.01      0.01
# Vacant housing units counts             4875.67   7410.68   4550.23   3914.41
# Vacant housing units counts percent        0.08      0.12      0.07      0.06
# Vacant housing units moe                 545.72    766.29    585.23    538.89
# Vacant housing units moa percent           0.07      0.06      0.08      0.08
# Homeowner vacancy rate counts             38.00     56.70     25.77     32.52
# Homeowner vacancy rate counts percent      0.07      0.10      0.05      0.06
# Homeowner vacancy rate moe                48.13     64.54     45.04     25.23
# Homeowner vacancy rate moa percent         0.77      0.69      1.06      0.47
# Rental vacancy rate counts               253.08    253.58    168.09    178.91
# Rental vacancy rate counts percent         0.10      0.10      0.07      0.07
# Rental vacancy rate moe                   54.43     74.98    124.30     82.81
# Rental vacancy rate moa percent            0.13      0.18      0.45      0.28

# %% [markdown]
# ### Units in structure

# %%
grouping = groups[1]
print(grouping)
print()

current_labels = labels [labels.label.str.contains(grouping)]
current_labels = current_labels.iloc[1:]
# current_labels = current_labels.iloc[:-16]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
# Out:
# UNITS IN STRUCTURE
#
# Estimate!!UNITS IN STRUCTURE!!Total housing units!!1-unit, detached
# Estimate!!UNITS IN STRUCTURE!!Total housing units!!1-unit, attached
# Estimate!!UNITS IN STRUCTURE!!Total housing units!!2 units
# Estimate!!UNITS IN STRUCTURE!!Total housing units!!3 or 4 units
# Estimate!!UNITS IN STRUCTURE!!Total housing units!!5 to 9 units
# Estimate!!UNITS IN STRUCTURE!!Total housing units!!10 to 19 units
# Estimate!!UNITS IN STRUCTURE!!Total housing units!!20 or more units
# Estimate!!UNITS IN STRUCTURE!!Total housing units!!Mobile home
# Estimate!!UNITS IN STRUCTURE!!Total housing units!!Boat, RV, van, etc.

# %%
final2 = cal_district_numbers(labels_check)    
final2
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in double_scalars
#                                             0         1         2         3  \
# 1-unit, detached counts             147676.57  31288.53  37142.12  37583.50
# 1-unit, detached counts percent          0.29      0.06      0.07      0.07
# 1-unit, detached moe                  2404.12   1072.21   1072.98   1094.90
# 1-unit, detached moa percent             0.01      0.02      0.02      0.02
# 1-unit, attached counts               3823.98   1294.55   1482.10    786.77
# 1-unit, attached counts percent          0.21      0.07      0.08      0.04
# 1-unit, attached moe                   473.00    313.38    352.38    201.74
# 1-unit, attached moa percent             0.08      0.15      0.14      0.16
# 2 units counts                         780.47   2730.82   1716.06   1353.51
# 2 units counts percent                   0.06      0.21      0.13      0.11
# 2 units moe                            250.01    384.30    381.73    255.48
# 2 units moa percent                      0.19      0.09      0.14      0.11
# 3 or 4 units counts                   3646.39   4038.61   3334.42   2424.99
# 3 or 4 units counts percent              0.10      0.11      0.09      0.07
# 3 or 4 units moe                       506.66    608.09    747.52    456.99
# 3 or 4 units moa percent                 0.08      0.09      0.14      0.11
# 5 to 9 units counts                   5271.37   4049.74   3277.88   2971.16
# 5 to 9 units counts percent              0.10      0.08      0.06      0.06
# 5 to 9 units moe                       613.73    510.37    420.47    395.88
# 5 to 9 units moa percent                 0.07      0.08      0.08      0.08
# 10 to 19 units counts                 6944.92   3682.14   3042.79   2757.21
# 10 to 19 units counts percent            0.12      0.07      0.05      0.05
# 10 to 19 units moe                     778.09    571.88    454.07    434.43
# 10 to 19 units moa percent               0.07      0.09      0.09      0.10
# 20 or more units counts               8442.83   9703.69   4675.38   3860.67
# 20 or more units counts percent          0.11      0.13      0.06      0.05
# 20 or more units moe                   727.07    635.38    530.18    527.89
# 20 or more units moa percent             0.05      0.04      0.07      0.08
# Mobile home counts                   11887.97    290.94   2511.01   2003.47
# Mobile home counts percent               0.55      0.01      0.12      0.09
# Mobile home moe                        848.39    143.44    339.57    262.22
# Mobile home moa percent                  0.04      0.30      0.08      0.08
# Boat, RV, van, etc. counts             187.13     44.00     72.50     77.11
# Boat, RV, van, etc. counts percent       0.38      0.09      0.15      0.16
# Boat, RV, van, etc. moe                173.00    106.68     93.73     92.93
# Boat, RV, van, etc. moa percent          0.56      1.47      0.79      0.73
#
#                                            4         5         6         7  \
# 1-unit, detached counts             33618.75  34393.06  41071.34  34854.69
# 1-unit, detached counts percent         0.07      0.07      0.08      0.07
# 1-unit, detached moe                  903.03   1057.59   1312.01   1103.70
# 1-unit, detached moa percent            0.02      0.02      0.02      0.02
# 1-unit, attached counts               813.48    908.83   1092.60   2582.26
# 1-unit, attached counts percent         0.05      0.05      0.06      0.14
# 1-unit, attached moe                  177.99    184.92    242.88    374.27
# 1-unit, attached moa percent            0.13      0.12      0.14      0.09
# 2 units counts                        845.43   1718.09    373.79   1037.67
# 2 units counts percent                  0.07      0.13      0.03      0.08
# 2 units moe                           355.46    340.13    187.01    270.98
# 2 units moa percent                     0.26      0.12      0.30      0.16
# 3 or 4 units counts                  1247.20   2164.36   1894.50   3939.69
# 3 or 4 units counts percent             0.03      0.06      0.05      0.11
# 3 or 4 units moe                      268.57    401.46    416.15    586.08
# 3 or 4 units moa percent                0.13      0.11      0.13      0.09
# 5 to 9 units counts                  1928.92   1915.01   4742.62   5434.85
# 5 to 9 units counts percent             0.04      0.04      0.09      0.11
# 5 to 9 units moe                      342.86    332.87    697.92    525.42
# 5 to 9 units moa percent                0.11      0.11      0.09      0.06
# 10 to 19 units counts                1813.10   1131.11   5785.89   6050.49
# 10 to 19 units counts percent           0.03      0.02      0.10      0.11
# 10 to 19 units moe                    361.79    320.81    720.75    693.84
# 10 to 19 units moa percent              0.12      0.17      0.08      0.07
# 20 or more units counts              1909.29   2969.10   5491.00   6985.11
# 20 or more units counts percent         0.03      0.04      0.07      0.09
# 20 or more units moe                  357.50    383.08    727.89    654.55
# 20 or more units moa percent            0.11      0.08      0.08      0.06
# Mobile home counts                   1503.54    341.39    867.80    467.79
# Mobile home counts percent              0.07      0.02      0.04      0.02
# Mobile home moe                       237.71    141.84    245.93    208.61
# Mobile home moa percent                 0.10      0.25      0.17      0.27
# Boat, RV, van, etc. counts             25.91      0.00      0.00      0.00
# Boat, RV, van, etc. counts percent      0.05      0.00      0.00      0.00
# Boat, RV, van, etc. moe                84.80     83.89     93.50     83.37
# Boat, RV, van, etc. moa percent         1.99       inf       inf       inf
#
#                                            8         9        10
# 1-unit, detached counts             29592.71  38040.00  41369.71
# 1-unit, detached counts percent         0.06      0.08      0.08
# 1-unit, detached moe                  958.50   1003.85   1027.02
# 1-unit, detached moa percent            0.02      0.02      0.02
# 1-unit, attached counts              1873.25   1542.99   1662.19
# 1-unit, attached counts percent         0.10      0.09      0.09
# 1-unit, attached moe                  341.35    360.71    293.56
# 1-unit, attached moa percent            0.11      0.14      0.11
# 2 units counts                        959.35    736.48    597.34
# 2 units counts percent                  0.07      0.06      0.05
# 2 units moe                           303.87    329.50    204.78
# 2 units moa percent                     0.19      0.27      0.21
# 3 or 4 units counts                  4665.32   3997.79   4477.72
# 3 or 4 units counts percent             0.13      0.11      0.12
# 3 or 4 units moe                      679.64    617.81    686.73
# 3 or 4 units moa percent                0.09      0.09      0.09
# 5 to 9 units counts                  9725.02   6996.47   4870.95
# 5 to 9 units counts percent             0.19      0.14      0.10
# 5 to 9 units moe                      912.47    816.29    563.61
# 5 to 9 units moa percent                0.06      0.07      0.07
# 10 to 19 units counts               12590.65   8896.57   3669.12
# 10 to 19 units counts percent           0.22      0.16      0.07
# 10 to 19 units moe                    939.81    833.91    509.95
# 10 to 19 units moa percent              0.05      0.06      0.08
# 20 or more units counts             17318.91   8758.61   5295.40
# 20 or more units counts percent         0.23      0.12      0.07
# 20 or more units moe                 1031.64    866.82    545.96
# 20 or more units moa percent            0.04      0.06      0.06
# Mobile home counts                    441.04    304.09    815.97
# Mobile home counts percent              0.02      0.01      0.04
# Mobile home moe                       164.40    141.79    223.01
# Mobile home moa percent                 0.23      0.28      0.17
# Boat, RV, van, etc. counts              0.00     10.59     78.75
# Boat, RV, van, etc. counts percent      0.00      0.02      0.16
# Boat, RV, van, etc. moe                92.95     90.08     93.33
# Boat, RV, van, etc. moa percent          inf      5.17      0.72

# %% [markdown]
# ### Year Built

# %%
grouping = groups[2]
print(grouping)
print()

current_labels = labels [labels.label.str.contains(grouping)]
current_labels = current_labels.iloc[1:]
# current_labels = current_labels.iloc[:-16]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
# Out:
# YEAR STRUCTURE BUILT
#
# Estimate!!YEAR STRUCTURE BUILT!!Total housing units!!Built 2020 or later
# Estimate!!YEAR STRUCTURE BUILT!!Total housing units!!Built 2010 to 2019
# Estimate!!YEAR STRUCTURE BUILT!!Total housing units!!Built 2000 to 2009
# Estimate!!YEAR STRUCTURE BUILT!!Total housing units!!Built 1990 to 1999
# Estimate!!YEAR STRUCTURE BUILT!!Total housing units!!Built 1980 to 1989
# Estimate!!YEAR STRUCTURE BUILT!!Total housing units!!Built 1970 to 1979
# Estimate!!YEAR STRUCTURE BUILT!!Total housing units!!Built 1960 to 1969
# Estimate!!YEAR STRUCTURE BUILT!!Total housing units!!Built 1950 to 1959
# Estimate!!YEAR STRUCTURE BUILT!!Total housing units!!Built 1940 to 1949
# Estimate!!YEAR STRUCTURE BUILT!!Total housing units!!Built 1939 or earlier

# %%
final3 = cal_district_numbers(labels_check)
final3
# Out:
#                                              0         1        2         3  \
# Built 2020 or later counts             1995.13     23.06   383.32     97.40
# Built 2020 or later counts percent        0.61      0.01     0.12      0.03
# Built 2020 or later moe                 396.65     87.30   173.70    111.17
# Built 2020 or later moa percent           0.12      2.30     0.28      0.69
# Built 2010 to 2019 counts             52936.95   3938.05  6617.04   5121.28
# Built 2010 to 2019 counts percent         0.46      0.03     0.06      0.04
# Built 2010 to 2019 moe                 1884.67    474.92   560.16    538.45
# Built 2010 to 2019 moa percent            0.02      0.07     0.05      0.06
# Built 2000 to 2009 counts             50935.18   2354.67  8214.46   5216.41
# Built 2000 to 2009 counts percent         0.37      0.02     0.06      0.04
# Built 2000 to 2009 moe                 1660.29    363.70   743.19    465.59
# Built 2000 to 2009 moa percent            0.02      0.09     0.05      0.05
# Built 1990 to 1999 counts             23479.96   2298.40  4192.64   3213.71
# Built 1990 to 1999 counts percent         0.24      0.02     0.04      0.03
# Built 1990 to 1999 moe                 1391.40    362.67   497.27    537.72
# Built 1990 to 1999 moa percent            0.04      0.10     0.07      0.10
# Built 1980 to 1989 counts             21826.21   4302.56  5741.22   3863.67
# Built 1980 to 1989 counts percent         0.19      0.04     0.05      0.03
# Built 1980 to 1989 moe                 1094.69    585.23   508.03    475.20
# Built 1980 to 1989 moa percent            0.03      0.08     0.05      0.07
# Built 1970 to 1979 counts             17817.47   5661.67  7603.81   6802.07
# Built 1970 to 1979 counts percent         0.17      0.06     0.07      0.07
# Built 1970 to 1979 moe                  992.03    614.34   724.39    649.91
# Built 1970 to 1979 moa percent            0.03      0.07     0.06      0.06
# Built 1960 to 1969 counts              9578.32   8347.80  8356.00   7677.36
# Built 1960 to 1969 counts percent         0.14      0.12     0.12      0.11
# Built 1960 to 1969 moe                  751.38    717.62   905.69    712.62
# Built 1960 to 1969 moa percent            0.05      0.05     0.07      0.06
# Built 1950 to 1959 counts              4226.51  12859.33  6806.28  10914.83
# Built 1950 to 1959 counts percent         0.07      0.21     0.11      0.17
# Built 1950 to 1959 moe                  473.99    912.84   555.17    730.08
# Built 1950 to 1959 moa percent            0.07      0.04     0.05      0.04
# Built 1940 to 1949 counts              2238.29   6891.28  3439.48   5854.51
# Built 1940 to 1949 counts percent         0.07      0.20     0.10      0.17
# Built 1940 to 1949 moe                  371.46    623.58   482.71    521.77
# Built 1940 to 1949 moa percent            0.10      0.06     0.09      0.05
# Built 1939 or earlier counts           3627.61  10446.20  5900.02   5057.16
# Built 1939 or earlier counts percent      0.10      0.30     0.17      0.14
# Built 1939 or earlier moe               428.19    630.88   477.53    476.78
# Built 1939 or earlier moa percent         0.07      0.04     0.05      0.06
#
#                                             4         5         6         7  \
# Built 2020 or later counts             120.84     35.40    170.64    149.37
# Built 2020 or later counts percent       0.04      0.01      0.05      0.05
# Built 2020 or later moe                105.52     86.49    159.35    124.80
# Built 2020 or later moa percent          0.53      1.49      0.57      0.51
# Built 2010 to 2019 counts             4058.69   1753.59   8611.38   3617.21
# Built 2010 to 2019 counts percent        0.04      0.02      0.08      0.03
# Built 2010 to 2019 moe                 477.90    298.37    684.53    430.40
# Built 2010 to 2019 moa percent           0.07      0.10      0.05      0.07
# Built 2000 to 2009 counts             9277.36   2839.46  12300.31   7481.27
# Built 2000 to 2009 counts percent        0.07      0.02      0.09      0.05
# Built 2000 to 2009 moe                 632.16    377.77    974.04    654.78
# Built 2000 to 2009 moa percent           0.04      0.08      0.05      0.05
# Built 1990 to 1999 counts             3956.37   2604.89  10263.57   9116.02
# Built 1990 to 1999 counts percent        0.04      0.03      0.10      0.09
# Built 1990 to 1999 moe                 438.67    362.98    850.80    662.75
# Built 1990 to 1999 moa percent           0.07      0.08      0.05      0.04
# Built 1980 to 1989 counts             5247.28   3024.93  13960.96  12258.48
# Built 1980 to 1989 counts percent        0.05      0.03      0.12      0.11
# Built 1980 to 1989 moe                 490.83    366.76    920.92    878.34
# Built 1980 to 1989 moa percent           0.06      0.07      0.04      0.04
# Built 1970 to 1979 counts             8032.16   3765.13   9287.92  10275.67
# Built 1970 to 1979 counts percent        0.08      0.04      0.09      0.10
# Built 1970 to 1979 moe                 590.83    456.62    848.76    730.95
# Built 1970 to 1979 moa percent           0.04      0.07      0.06      0.04
# Built 1960 to 1969 counts             7521.07   6061.04   3699.13   7343.85
# Built 1960 to 1969 counts percent        0.11      0.09      0.05      0.10
# Built 1960 to 1969 moe                 763.22    618.58    440.80    615.25
# Built 1960 to 1969 moa percent           0.06      0.06      0.07      0.05
# Built 1950 to 1959 counts             3416.54  10689.97   1724.88   6058.15
# Built 1950 to 1959 counts percent        0.05      0.17      0.03      0.10
# Built 1950 to 1959 moe                 412.73    893.65    298.11    722.38
# Built 1950 to 1959 moa percent           0.07      0.05      0.11      0.07
# Built 1940 to 1949 counts             1403.79   8435.02   1040.49   3290.37
# Built 1940 to 1949 counts percent        0.04      0.25      0.03      0.10
# Built 1940 to 1949 moe                 270.62    630.88    280.69    491.19
# Built 1940 to 1949 moa percent           0.12      0.05      0.16      0.09
# Built 1939 or earlier counts           671.54   6331.53    260.25   1762.16
# Built 1939 or earlier counts percent     0.02      0.18      0.01      0.05
# Built 1939 or earlier moe              182.51    601.01    138.66    278.65
# Built 1939 or earlier moa percent        0.17      0.06      0.32      0.10
#
#                                              8         9        10
# Built 2020 or later counts               77.78    135.74     88.31
# Built 2020 or later counts percent        0.02      0.04      0.03
# Built 2020 or later moe                 105.77    133.81    101.21
# Built 2020 or later moa percent           0.83      0.60      0.70
# Built 2010 to 2019 counts             14767.07   7879.29   5492.46
# Built 2010 to 2019 counts percent         0.13      0.07      0.05
# Built 2010 to 2019 moe                  865.80    677.80    522.21
# Built 2010 to 2019 moa percent            0.04      0.05      0.06
# Built 2000 to 2009 counts             15997.61  14832.76   9556.50
# Built 2000 to 2009 counts percent         0.12      0.11      0.07
# Built 2000 to 2009 moe                  919.45    884.49    790.88
# Built 2000 to 2009 moa percent            0.03      0.04      0.05
# Built 1990 to 1999 counts             14376.78  16213.96   9735.68
# Built 1990 to 1999 counts percent         0.14      0.16      0.10
# Built 1990 to 1999 moe                  965.99   1010.59    644.72
# Built 1990 to 1999 moa percent            0.04      0.04      0.04
# Built 1980 to 1989 counts             16498.79  15113.55  14552.35
# Built 1980 to 1989 counts percent         0.14      0.13      0.13
# Built 1980 to 1989 moe                 1001.33   1055.03    825.11
# Built 1980 to 1989 moa percent            0.04      0.04      0.03
# Built 1970 to 1979 counts             10748.80   9273.58  13645.74
# Built 1970 to 1979 counts percent         0.10      0.09      0.13
# Built 1970 to 1979 moe                  798.67    715.44    831.99
# Built 1970 to 1979 moa percent            0.05      0.05      0.04
# Built 1960 to 1969 counts              3320.41   4121.35   4412.69
# Built 1960 to 1969 counts percent         0.05      0.06      0.06
# Built 1960 to 1969 moe                  464.27    394.27    482.09
# Built 1960 to 1969 moa percent            0.08      0.06      0.07
# Built 1950 to 1959 counts               853.09   1063.78   3996.64
# Built 1950 to 1959 counts percent         0.01      0.02      0.06
# Built 1950 to 1959 moe                  235.22    291.45    462.33
# Built 1950 to 1959 moa percent            0.17      0.17      0.07
# Built 1940 to 1949 counts               155.08    244.05   1077.66
# Built 1940 to 1949 counts percent         0.00      0.01      0.03
# Built 1940 to 1949 moe                  109.56    128.26    243.65
# Built 1940 to 1949 moa percent            0.43      0.32      0.14
# Built 1939 or earlier counts            370.86    405.54    279.14
# Built 1939 or earlier counts percent      0.01      0.01      0.01
# Built 1939 or earlier moe               182.88    165.99    154.82
# Built 1939 or earlier moa percent         0.30      0.25      0.34

# %% [markdown]
# ### Rooms

# %%
grouping = groups[3]
print(grouping)
print()

current_labels = labels [labels.label.str.contains(grouping)]
current_labels = current_labels.iloc[1:]
current_labels = current_labels.iloc[:-7]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
# Out:
# ROOMS
#
# Estimate!!ROOMS!!Total housing units!!1 room
# Estimate!!ROOMS!!Total housing units!!2 rooms
# Estimate!!ROOMS!!Total housing units!!3 rooms
# Estimate!!ROOMS!!Total housing units!!4 rooms
# Estimate!!ROOMS!!Total housing units!!5 rooms
# Estimate!!ROOMS!!Total housing units!!6 rooms
# Estimate!!ROOMS!!Total housing units!!7 rooms
# Estimate!!ROOMS!!Total housing units!!8 rooms
# Estimate!!ROOMS!!Total housing units!!9 rooms or more
# Estimate!!ROOMS!!Total housing units!!Median rooms

# %%
final4 = cal_district_numbers(labels_check)
final4
# Out:
#                                        0         1         2         3  \
# 1 room counts                    2636.95   3387.01   1534.98   1686.14
# 1 room counts percent               0.12      0.15      0.07      0.08
# 1 room moe                        465.47    509.71    304.17    325.98
# 1 room moa percent                  0.11      0.09      0.12      0.12
# 2 rooms counts                   4203.58   2928.19   2565.53   2367.18
# 2 rooms counts percent              0.13      0.09      0.08      0.08
# 2 rooms moe                       590.44    388.62    471.35    457.31
# 2 rooms moa percent                 0.09      0.08      0.11      0.12
# 3 rooms counts                   9216.77   9740.80   6170.45   5560.06
# 3 rooms counts percent              0.11      0.12      0.08      0.07
# 3 rooms moe                       833.82    792.70    757.30    573.54
# 3 rooms moa percent                 0.05      0.05      0.07      0.06
# 4 rooms counts                  19656.15  10746.93  10530.95   9300.08
# 4 rooms counts percent              0.16      0.09      0.09      0.08
# 4 rooms moe                      1169.46    872.48    849.35    714.60
# 4 rooms moa percent                 0.04      0.05      0.05      0.05
# 5 rooms counts                  32745.01  12526.23  12825.85  13872.91
# 5 rooms counts percent              0.22      0.08      0.08      0.09
# 5 rooms moe                      1501.63    839.21    803.58    956.56
# 5 rooms moa percent                 0.03      0.04      0.04      0.04
# 6 rooms counts                  37256.39   9436.26  12034.39  11715.67
# 6 rooms counts percent              0.26      0.07      0.08      0.08
# 6 rooms moe                      1798.80    792.58    781.94    771.89
# 6 rooms moa percent                 0.03      0.05      0.04      0.04
# 7 rooms counts                  27985.99   3888.74   6042.49   5028.29
# 7 rooms counts percent              0.32      0.04      0.07      0.06
# 7 rooms moe                      1392.26    483.71    686.35    562.80
# 7 rooms moa percent                 0.03      0.08      0.07      0.07
# 8 rooms counts                  23604.87   2132.40   3155.26   2168.90
# 8 rooms counts percent              0.37      0.03      0.05      0.03
# 8 rooms moe                      1333.67    308.22    409.71    318.77
# 8 rooms moa percent                 0.03      0.09      0.08      0.09
# 9 rooms or more counts          31355.94   2336.46   2394.36   2119.16
# 9 rooms or more counts percent      0.42      0.03      0.03      0.03
# 9 rooms or more moe              1302.75    316.29    372.80    345.56
# 9 rooms or more moa percent         0.03      0.08      0.09      0.10
# Median rooms counts               504.25    140.41    155.79    153.97
# Median rooms counts percent         0.25      0.07      0.08      0.08
# Median rooms moe                    3.88      2.02      2.05      2.04
# Median rooms moa percent            0.00      0.01      0.01      0.01
#
#                                        4         5         6         7  \
# 1 room counts                     800.65   1435.98   1528.63   2015.08
# 1 room counts percent               0.04      0.07      0.07      0.09
# 1 room moe                        253.84    289.52    352.19    353.45
# 1 room moa percent                  0.19      0.12      0.14      0.11
# 2 rooms counts                   1102.82   1248.58   2458.20   2661.25
# 2 rooms counts percent              0.04      0.04      0.08      0.08
# 2 rooms moe                       240.17    295.28    490.88    451.05
# 2 rooms moa percent                 0.13      0.14      0.12      0.10
# 3 rooms counts                   3339.41   5204.89   5729.25   6947.85
# 3 rooms counts percent              0.04      0.06      0.07      0.09
# 3 rooms moe                       466.28    600.69    768.27    688.67
# 3 rooms moa percent                 0.08      0.07      0.08      0.06
# 4 rooms counts                   5881.89  10626.16   8985.97  11263.31
# 4 rooms counts percent              0.05      0.09      0.07      0.09
# 4 rooms moe                       564.55    809.02    840.89    841.76
# 4 rooms moa percent                 0.06      0.05      0.06      0.05
# 5 rooms counts                  11774.55  12795.09  13182.07  12446.66
# 5 rooms counts percent              0.08      0.08      0.09      0.08
# 5 rooms moe                       882.74    844.66    949.38    936.86
# 5 rooms moa percent                 0.05      0.04      0.04      0.05
# 6 rooms counts                  10296.03   8151.12  12471.27  11564.78
# 6 rooms counts percent              0.07      0.06      0.09      0.08
# 6 rooms moe                       793.55    623.87    875.77    800.86
# 6 rooms moa percent                 0.05      0.05      0.04      0.04
# 7 rooms counts                   5316.61   3314.53   7932.56   6602.76
# 7 rooms counts percent              0.06      0.04      0.09      0.07
# 7 rooms moe                       531.08    382.53    929.44    563.99
# 7 rooms moa percent                 0.06      0.07      0.07      0.05
# 8 rooms counts                   2947.22   1342.85   4727.35   4293.38
# 8 rooms counts percent              0.05      0.02      0.07      0.07
# 8 rooms moe                       357.44    209.58    615.23    502.48
# 8 rooms moa percent                 0.07      0.09      0.08      0.07
# 9 rooms or more counts           2246.44   1421.75   4304.21   3557.47
# 9 rooms or more counts percent      0.03      0.02      0.06      0.05
# 9 rooms or more moe               359.93    425.27    602.35    398.18
# 9 rooms or more moa percent         0.10      0.18      0.09      0.07
# Median rooms counts               126.16    136.03    149.70    157.56
# Median rooms counts percent         0.06      0.07      0.07      0.08
# Median rooms moe                    1.57      1.68      2.16      2.05
# Median rooms moa percent            0.01      0.01      0.01      0.01
#
#                                        8         9        10
# 1 room counts                    3676.73   1649.37   1616.48
# 1 room counts percent               0.17      0.08      0.07
# 1 room moe                        536.45    465.64    384.33
# 1 room moa percent                  0.09      0.17      0.14
# 2 rooms counts                   6580.10   2923.77   2349.78
# 2 rooms counts percent              0.21      0.09      0.07
# 2 rooms moe                       739.34    468.23    409.96
# 2 rooms moa percent                 0.07      0.10      0.11
# 3 rooms counts                  14029.09   9870.13   5875.29
# 3 rooms counts percent              0.17      0.12      0.07
# 3 rooms moe                      1002.50    934.86    572.04
# 3 rooms moa percent                 0.04      0.06      0.06
# 4 rooms counts                  15257.30  11296.32   9023.92
# 4 rooms counts percent              0.12      0.09      0.07
# 4 rooms moe                      1091.40   1024.31    795.63
# 4 rooms moa percent                 0.04      0.06      0.05
# 5 rooms counts                  10298.58   7474.01  12055.03
# 5 rooms counts percent              0.07      0.05      0.08
# 5 rooms moe                       890.47    696.89    829.47
# 5 rooms moa percent                 0.05      0.06      0.04
# 6 rooms counts                   8460.96   8063.97  13104.16
# 6 rooms counts percent              0.06      0.06      0.09
# 6 rooms moe                       688.80    714.94    877.53
# 6 rooms moa percent                 0.05      0.05      0.04
# 7 rooms counts                   6687.25   7744.57   7505.20
# 7 rooms counts percent              0.08      0.09      0.09
# 7 rooms moe                       573.52    722.12    588.79
# 7 rooms moa percent                 0.05      0.06      0.05
# 8 rooms counts                   5946.16   7670.53   5769.08
# 8 rooms counts percent              0.09      0.12      0.09
# 8 rooms moe                       571.65    602.75    544.85
# 8 rooms moa percent                 0.06      0.05      0.06
# 9 rooms or more counts           6230.07  12590.93   5538.21
# 9 rooms or more counts percent      0.08      0.17      0.07
# 9 rooms or more moe               598.94    663.98    544.70
# 9 rooms or more moa percent         0.06      0.03      0.06
# Median rooms counts               147.81    182.77    155.95
# Median rooms counts percent         0.07      0.09      0.08
# Median rooms moe                    2.05      2.71      1.99
# Median rooms moa percent            0.01      0.01      0.01

# %% [markdown]
# ### Bedrooms

# %%
grouping = groups[4]
print(grouping)
print()

current_labels = labels [labels.label.str.contains(grouping)]
current_labels = current_labels.iloc[1:]
# current_labels = current_labels.iloc[:-16]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
# Out:
# BEDROOMS
#
# Estimate!!BEDROOMS!!Total housing units!!No bedroom
# Estimate!!BEDROOMS!!Total housing units!!1 bedroom
# Estimate!!BEDROOMS!!Total housing units!!2 bedrooms
# Estimate!!BEDROOMS!!Total housing units!!3 bedrooms
# Estimate!!BEDROOMS!!Total housing units!!4 bedrooms
# Estimate!!BEDROOMS!!Total housing units!!5 or more bedrooms

# %%
final5 = cal_district_numbers(labels_check)
final5
# Out:
#                                           0         1         2         3  \
# No bedroom counts                   2916.44   3671.44   1598.19   1745.86
# No bedroom counts percent              0.13      0.16      0.07      0.07
# No bedroom moe                       486.49    518.43    305.27    327.22
# No bedroom moa percent                 0.10      0.09      0.12      0.11
# 1 bedroom counts                   11274.86  13418.91   8716.29   7215.44
# 1 bedroom counts percent               0.10      0.12      0.08      0.06
# 1 bedroom moe                        849.15    863.71    904.12    682.10
# 1 bedroom moa percent                  0.05      0.04      0.06      0.06
# 2 bedrooms counts                  21181.36  17643.25  14543.70  14551.06
# 2 bedrooms counts percent              0.13      0.11      0.09      0.09
# 2 bedrooms moe                      1112.87    951.43    892.81    796.78
# 2 bedrooms moa percent                 0.03      0.03      0.04      0.03
# 3 bedrooms counts                  85586.75  17639.88  24026.24  23468.14
# 3 bedrooms counts percent              0.28      0.06      0.08      0.08
# 3 bedrooms moe                      2264.74    959.60    951.03   1066.40
# 3 bedrooms moa percent                 0.02      0.03      0.02      0.03
# 4 bedrooms counts                  55152.83   4057.77   7363.82   6080.64
# 4 bedrooms counts percent              0.38      0.03      0.05      0.04
# 4 bedrooms moe                      1853.69    553.92    724.79    600.85
# 4 bedrooms moa percent                 0.02      0.08      0.06      0.06
# 5 or more bedrooms counts          12549.40    691.77   1006.04    757.26
# 5 or more bedrooms counts percent      0.46      0.03      0.04      0.03
# 5 or more bedrooms moe               911.99    177.46    212.73    187.85
# 5 or more bedrooms moa percent         0.04      0.16      0.13      0.15
#
#                                           4         5         6         7  \
# No bedroom counts                    909.37   1485.16   1598.26   2188.76
# No bedroom counts percent              0.04      0.06      0.07      0.09
# No bedroom moe                       259.66    292.35    356.79    367.94
# No bedroom moa percent                 0.17      0.12      0.14      0.10
# 1 bedroom counts                    3511.28   6751.31   8120.70  10500.16
# 1 bedroom counts percent               0.03      0.06      0.07      0.09
# 1 bedroom moe                        450.00    637.12    793.32    801.90
# 1 bedroom moa percent                  0.08      0.06      0.06      0.05
# 2 bedrooms counts                   6900.60  16174.65  11489.65  15068.67
# 2 bedrooms counts percent              0.04      0.10      0.07      0.09
# 2 bedrooms moe                       672.98    987.69    974.82    907.77
# 2 bedrooms moa percent                 0.06      0.04      0.05      0.04
# 3 bedrooms counts                  22854.57  17098.65  27189.89  24638.66
# 3 bedrooms counts percent              0.07      0.06      0.09      0.08
# 3 bedrooms moe                       947.44    882.94   1181.99   1141.26
# 3 bedrooms moa percent                 0.03      0.03      0.03      0.03
# 4 bedrooms counts                   8589.95   3413.61  11268.76   7980.99
# 4 bedrooms counts percent              0.06      0.02      0.08      0.06
# 4 bedrooms moe                       639.74    411.18    979.43    668.93
# 4 bedrooms moa percent                 0.05      0.07      0.05      0.05
# 5 or more bedrooms counts            939.86    617.59   1652.28    975.31
# 5 or more bedrooms counts percent      0.03      0.02      0.06      0.04
# 5 or more bedrooms moe               213.90    179.24    375.63    198.32
# 5 or more bedrooms moa percent         0.14      0.18      0.14      0.12
#
#                                           8         9        10
# No bedroom counts                   3757.39   1776.66   1679.48
# No bedroom counts percent              0.16      0.08      0.07
# No bedroom moe                       537.93    474.77    387.45
# No bedroom moa percent                 0.09      0.16      0.14
# 1 bedroom counts                   19920.22  14169.63   8096.21
# 1 bedroom counts percent               0.18      0.13      0.07
# 1 bedroom moe                       1137.13    978.74    650.30
# 1 bedroom moa percent                  0.03      0.04      0.05
# 2 bedrooms counts                  20639.60  14724.61  12081.84
# 2 bedrooms counts percent              0.13      0.09      0.07
# 2 bedrooms moe                      1192.28   1091.48    887.05
# 2 bedrooms moa percent                 0.04      0.05      0.04
# 3 bedrooms counts                  18315.20  17821.39  27315.64
# 3 bedrooms counts percent              0.06      0.06      0.09
# 3 bedrooms moe                       938.94    948.92   1100.30
# 3 bedrooms moa percent                 0.03      0.03      0.02
# 4 bedrooms counts                  12421.89  16308.60  12146.14
# 4 bedrooms counts percent              0.09      0.11      0.08
# 4 bedrooms moe                       722.68    830.23    719.08
# 4 bedrooms moa percent                 0.04      0.03      0.04
# 5 or more bedrooms counts           2111.95   4482.70   1517.84
# 5 or more bedrooms counts percent      0.08      0.16      0.06
# 5 or more bedrooms moe               336.34    428.97    292.25
# 5 or more bedrooms moa percent         0.10      0.06      0.12

# %% [markdown]
# ### Tenure

# %%
grouping = groups[5]
print(grouping)
print()

current_labels = labels [labels.label.str.contains(grouping)]
current_labels = current_labels.iloc[1:]
# current_labels = current_labels.iloc[:-2]
labels_check = current_labels.column_name.str[:-1]

for titles in current_labels.label:
    print(titles)
# Out:
# HOUSING TENURE
#
# Estimate!!HOUSING TENURE!!Occupied housing units!!Owner-occupied
# Estimate!!HOUSING TENURE!!Occupied housing units!!Renter-occupied
# Estimate!!HOUSING TENURE!!Occupied housing units!!Average household size of owner-occupied unit
# Estimate!!HOUSING TENURE!!Occupied housing units!!Average household size of renter-occupied unit

# %%
final6 = cal_district_numbers(labels_check)
final6
# Out:
#                                                             0         1  \
# Owner-occupied counts                               134220.34  22401.87
# Owner-occupied counts percent                            0.32      0.05
# Owner-occupied moe                                    2410.04    981.96
# Owner-occupied moa percent                               0.01      0.03
# Renter-occupied counts                               43109.46  27372.44
# Renter-occupied counts percent                           0.15      0.09
# Renter-occupied moe                                   1604.82   1146.73
# Renter-occupied moa percent                              0.02      0.03
# Average household size of owner-occupied unit c...     236.19     82.43
# Average household size of owner-occupied unit c...       0.22      0.08
# Average household size of owner-occupied unit moe        3.12      2.69
# Average household size of owner-occupied unit m...       0.01      0.02
# Average household size of renter-occupied unit ...     237.49     72.71
# Average household size of renter-occupied unit ...       0.24      0.07
# Average household size of renter-occupied unit moe       6.57      2.56
# Average household size of renter-occupied unit ...       0.02      0.02
#
#                                                            2         3  \
# Owner-occupied counts                               25273.12  29062.45
# Owner-occupied counts percent                           0.06      0.07
# Owner-occupied moe                                   1018.04   1065.10
# Owner-occupied moa percent                              0.02      0.02
# Renter-occupied counts                              25949.01  20037.69
# Renter-occupied counts percent                          0.09      0.07
# Renter-occupied moe                                  1262.25   1006.22
# Renter-occupied moa percent                             0.03      0.03
# Average household size of owner-occupied unit c...     91.20     90.45
# Average household size of owner-occupied unit c...      0.09      0.09
# Average household size of owner-occupied unit moe       4.09      2.28
# Average household size of owner-occupied unit m...      0.03      0.02
# Average household size of renter-occupied unit ...     81.82     82.09
# Average household size of renter-occupied unit ...      0.08      0.08
# Average household size of renter-occupied unit moe      2.64      2.85
# Average household size of renter-occupied unit ...      0.02      0.02
#
#                                                            4         5  \
# Owner-occupied counts                               25749.50  22986.08
# Owner-occupied counts percent                           0.06      0.05
# Owner-occupied moe                                    916.31    951.43
# Owner-occupied moa percent                              0.02      0.03
# Renter-occupied counts                              15135.03  17975.83
# Renter-occupied counts percent                          0.05      0.06
# Renter-occupied moe                                   871.02    935.41
# Renter-occupied moa percent                             0.03      0.03
# Average household size of owner-occupied unit c...     74.82     86.13
# Average household size of owner-occupied unit c...      0.07      0.08
# Average household size of owner-occupied unit moe       2.27      3.59
# Average household size of owner-occupied unit m...      0.02      0.03
# Average household size of renter-occupied unit ...     76.74     86.09
# Average household size of renter-occupied unit ...      0.08      0.09
# Average household size of renter-occupied unit moe      2.76      3.32
# Average household size of renter-occupied unit ...      0.02      0.02
#
#                                                            6         7  \
# Owner-occupied counts                               33563.21  29316.87
# Owner-occupied counts percent                           0.08      0.07
# Owner-occupied moe                                   1277.99   1116.46
# Owner-occupied moa percent                              0.02      0.02
# Renter-occupied counts                              24399.40  27160.01
# Renter-occupied counts percent                          0.08      0.09
# Renter-occupied moe                                  1173.05   1112.32
# Renter-occupied moa percent                             0.03      0.02
# Average household size of owner-occupied unit c...     85.67     81.78
# Average household size of owner-occupied unit c...      0.08      0.08
# Average household size of owner-occupied unit moe       2.53      2.34
# Average household size of owner-occupied unit m...      0.02      0.02
# Average household size of renter-occupied unit ...     77.16     78.37
# Average household size of renter-occupied unit ...      0.08      0.08
# Average household size of renter-occupied unit moe      3.43      2.77
# Average household size of renter-occupied unit ...      0.03      0.02
#
#                                                            8         9  \
# Owner-occupied counts                               26933.87  35075.54
# Owner-occupied counts percent                           0.06      0.08
# Owner-occupied moe                                    955.98    919.42
# Owner-occupied moa percent                              0.02      0.02
# Renter-occupied counts                              42821.70  29657.82
# Renter-occupied counts percent                          0.14      0.10
# Renter-occupied moe                                  1451.17   1351.58
# Renter-occupied moa percent                             0.02      0.03
# Average household size of owner-occupied unit c...     72.96     80.73
# Average household size of owner-occupied unit c...      0.07      0.08
# Average household size of owner-occupied unit moe       2.08      1.78
# Average household size of owner-occupied unit m...      0.02      0.01
# Average household size of renter-occupied unit ...     68.21     63.15
# Average household size of renter-occupied unit ...      0.07      0.06
# Average household size of renter-occupied unit moe      2.30      2.56
# Average household size of renter-occupied unit ...      0.02      0.02
#
#                                                           10
# Owner-occupied counts                               36302.14
# Owner-occupied counts percent                           0.09
# Owner-occupied moe                                   1105.32
# Owner-occupied moa percent                              0.02
# Renter-occupied counts                              22620.61
# Renter-occupied counts percent                          0.08
# Renter-occupied moe                                   959.39
# Renter-occupied moa percent                             0.03
# Average household size of owner-occupied unit c...     73.62
# Average household size of owner-occupied unit c...      0.07
# Average household size of owner-occupied unit moe       1.65
# Average household size of owner-occupied unit m...      0.01
# Average household size of renter-occupied unit ...     69.93
# Average household size of renter-occupied unit ...      0.07
# Average household size of renter-occupied unit moe      3.07
# Average household size of renter-occupied unit ...      0.03

# %%
# Out:
# 17

# %%
with pd.ExcelWriter('sa2020_ccd_housing.xlsx') as writer:
    final0.to_excel(writer, sheet_name='Total Housing Units')
    final1.to_excel(writer, sheet_name=groups[0])
    final2.to_excel(writer, sheet_name=groups[1])
    final3.to_excel(writer, sheet_name=groups[2])
    final4.to_excel(writer, sheet_name=groups[3])
    final5.to_excel(writer, sheet_name=groups[4])
    final6.to_excel(writer, sheet_name=groups[5])
